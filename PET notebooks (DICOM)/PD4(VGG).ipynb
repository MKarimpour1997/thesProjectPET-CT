# %%
# !pip install pydicom

import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import keras
import cv2
import pickle
import sklearn
import pydicom
import random

from sklearn.metrics import auc, f1_score, roc_curve, recall_score, precision_score, accuracy_score, confusion_matrix
from sklearn import metrics
from google.colab import files
from keras.preprocessing import image
from keras.layers.serialization import activation
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import *
from keras.layers import Dense, GlobalAveragePooling2D, Flatten
from keras.models import Model
from keras import backend as K
from tensorflow.keras import layers, Model
from keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img

tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
# !pip install h5py pyyaml
# Out:
# Collecting pydicom
#   Downloading pydicom-2.4.3-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.4 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-2.4.3
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.9.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (6.0.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py) (1.23.5)

# %% [markdown]
# ##**Data Directory**

# %%
base_dir = '/content/drive/MyDrive/PETonlyWholeDataset'

training_set_dir = os.path.join(base_dir, 'trainingSet')
test_set_dir = os.path.join(base_dir, 'testSet')

train_lungCancer_dir = os.path.join(training_set_dir, 'lungCancer')
train_normal_dir = os.path.join(training_set_dir, 'normal')
test_lungCancer_dir = os.path.join(test_set_dir, 'lungCancer')
test_normal_dir = os.path.join(test_set_dir, 'normal')

# %%
train_lungCancer_names = os.listdir(train_lungCancer_dir)
print(train_lungCancer_names[:10])

train_normal_names = os.listdir(train_normal_dir)
print(train_normal_names[:10])
# Out:
# ['00000094 (18).dcm', '00000094 (5).dcm', '00000094 (8).dcm', '00000094 (1).dcm', '00000094 (9).dcm', '00000094 (16).dcm', '00000094 (2).dcm', '00000094 (3).dcm', '00000094 (14).dcm', '00000094 (10).dcm']
# ['00000001 (9).dcm', '00000001 (23).dcm', '00000001 (6).dcm', '00000001 (13).dcm', '00000001 (17).dcm', '00000001 (16).dcm', '00000001 (21).dcm', '00000001 (20).dcm', '00000001 (31).dcm', '00000001 (19).dcm']

# %%
print('total training lungCancer images:', len(os.listdir(train_lungCancer_dir)))
print('total training normal images:', len(os.listdir(train_normal_dir)))
print('total test lungCancer images:', len(os.listdir(test_lungCancer_dir)))
print('total test normal images:', len(os.listdir(test_normal_dir)))
# Out:
# total training lungCancer images: 811
# total training normal images: 809
# total test lungCancer images: 205
# total test normal images: 200

# %% [markdown]
# ##**Checking Patient Overlap**

# %%
def check_data_leakage(directory1, directory2):
    filenames_dir1 = set(os.listdir(directory1))
    filenames_dir2 = set(os.listdir(directory2))

    common_filenames = filenames_dir1.intersection(filenames_dir2)

    if len(common_filenames) > 0:
        print("Data leakage detected!")
        print("Common image filenames between the directories:", common_filenames)
    else:
        print("No data leakage detected.")

# %%
check_data_leakage(train_lungCancer_dir, test_lungCancer_dir)
check_data_leakage(train_normal_dir, test_normal_dir)
check_data_leakage(train_lungCancer_dir, test_normal_dir)
check_data_leakage(train_normal_dir, test_lungCancer_dir)
# Out:
# No data leakage detected.
# No data leakage detected.
# No data leakage detected.
# No data leakage detected.

# %% [markdown]
# ##**Data Visualization**

# %%
def display_random_dicom_images(directory, num_images=3):
    filenames = os.listdir(directory)
    random_images = random.sample(filenames, num_images)

    for filename in random_images:
        dicom_filepath = os.path.join(directory, filename)
        dicom_data = pydicom.dcmread(dicom_filepath)

        plt.imshow(dicom_data.pixel_array, cmap=plt.cm.bone)
        plt.title(f"Subdirectory: {os.path.basename(directory)}")
        plt.axis('off')
        plt.show()

display_random_dicom_images(test_lungCancer_dir, num_images=3)

# %%
def display_random_dicom_images(directory, num_images=3):
    filenames = os.listdir(directory)
    random_images = random.sample(filenames, num_images)

    for filename in random_images:
        dicom_filepath = os.path.join(directory, filename)
        dicom_data = pydicom.dcmread(dicom_filepath)
        image = dicom_data.pixel_array
        cropped_image = image[30:, :]
        print(cropped_image.shape)

        plt.imshow(cropped_image, cmap=plt.cm.bone)
        plt.title(f"Subdirectory: {os.path.basename(directory)}")
        plt.axis('off')
        plt.show()

display_random_dicom_images(test_lungCancer_dir, num_images=3)
# Out:
# (114, 144)
# (114, 144)
# (114, 144)

# %% [markdown]
# ##Data loading

# %%
def load_and_preprocess_dicom(dcm_path, crop_start):
    dcm_data = pydicom.dcmread(dcm_path)
    image = dcm_data.pixel_array.astype(np.float32) / 255.0

    cropped_image = image[crop_start:, :]

    image_single_channel = np.expand_dims(cropped_image, axis=-1)

    image_rgb = np.concatenate([image_single_channel] * 3, axis=-1)

    resized_image = tf.image.resize(image_rgb, (114, 144))

    return resized_image

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest')


train_images = np.array([load_and_preprocess_dicom(os.path.join(train_lungCancer_dir, filename), 30) for filename in os.listdir(train_lungCancer_dir) if filename.endswith('.dcm')])
train_labels = np.array([1] * len(train_images))

normal_train_images = np.array([load_and_preprocess_dicom(os.path.join(train_normal_dir, filename), 30) for filename in os.listdir(train_normal_dir) if filename.endswith('.dcm')])
normal_train_labels = np.array([0] * len(normal_train_images))

train_images = np.concatenate((train_images, normal_train_images))
train_labels = np.concatenate((train_labels, normal_train_labels))

train_generator = train_datagen.flow(train_images, train_labels, batch_size=40, shuffle=True)

test_images = np.array([load_and_preprocess_dicom(os.path.join(test_lungCancer_dir, filename), 30) for filename in os.listdir(test_lungCancer_dir) if filename.endswith('.dcm')])
test_labels = np.array([1] * len(test_images))

normal_test_images = np.array([load_and_preprocess_dicom(os.path.join(test_normal_dir, filename), 30) for filename in os.listdir(test_normal_dir) if filename.endswith('.dcm')])
normal_test_labels = np.array([0] * len(normal_test_images))

test_images = np.concatenate((test_images, normal_test_images))
test_labels = np.concatenate((test_labels, normal_test_labels))

# %% [markdown]
# ##**Model defining and compiling**

# %%
pre_trained_model = VGG19(include_top=False, weights='imagenet', input_shape=(114, 144, 3))

for layer in pre_trained_model.layers:
    layer.trainable = True

pre_trained_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 1s 0us/step
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 114, 144, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 114, 144, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 114, 144, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 57, 72, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 57, 72, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 57, 72, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 28, 36, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 28, 36, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 28, 36, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 28, 36, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 28, 36, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 14, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 14, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 14, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 14, 18, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 14, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 7, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 7, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 7, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 7, 9, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 7, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 4, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
last_layer = pre_trained_model.get_layer('block5_pool')
print('last layer output shape:', last_layer.output_shape)
last_output = last_layer.output

x = layers.Flatten()(last_output)
x = Dense(512, activation='relu')(x)
x = Dense(256, activation='relu')(x)
x = Dense(128, activation='relu')(x)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
x = Dense(1, activation='sigmoid')(x)


model = Model(pre_trained_model.input, x)
# Out:
# last layer output shape: (None, 3, 4, 512)

# %%
model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=[tf.keras.metrics.BinaryAccuracy(name="Binary_accuracy"),
                       tf.keras.metrics.Precision(name='Precision'),
                       tf.keras.metrics.Recall(name='Recall'),
                       tf.keras.metrics.TruePositives(name='TP'),
                       tf.keras.metrics.TrueNegatives(name='TN'),
                       tf.keras.metrics.FalseNegatives(name='FN'),
                       tf.keras.metrics.FalsePositives(name='FP'),
                       tf.keras.metrics.AUC(name='AUC')])

history = model.fit(train_generator, validation_data=(test_images, test_labels), epochs = 20,
            verbose = 1)
# Out:
# Epoch 1/20
# 41/41 [==============================] - 43s 470ms/step - loss: 0.8342 - Binary_accuracy: 0.5105 - Precision: 0.5090 - Recall: 0.6276 - TP: 509.0000 - TN: 318.0000 - FN: 302.0000 - FP: 491.0000 - AUC: 0.5082 - val_loss: 0.6952 - val_Binary_accuracy: 0.4938 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val
0000 - val_FP: 200.0000 - val_AUC: 0.3634
# Epoch 17/20
# 41/41 [==============================] - 11s 269ms/step - loss: 0.6932 - Binary_accuracy: 0.4944 - Precision: 0.4967 - Recall: 0.7472 - TP: 606.0000 - TN: 195.0000 - FN: 205.0000 - FP: 614.0000 - AUC: 0.5000 - val_loss: 0.6958 - val_Binary_accuracy: 0.2988 - val_Precision: 0.3769 - val_Recall: 0.5902 - val_TP: 121.0000 - val_TN: 0.0000e+00 - val_FN: 84.0000 - val_FP: 200.0000 - val_AUC: 0.3634
# Epoch 18/20
# 41/41 [==============================] - 12s 292ms/step - loss: 0.6932 - Binary_accuracy: 0.5006 - Precision: 0.5006 - Recall: 1.0000 - TP: 811.0000 - TN: 0.0000e+00 - FN: 0.0000e+00 - FP: 809.0000 - AUC: 0.5000 - val_loss: 0.6959 - val_Binary_accuracy: 0.2963 - val_Precision: 0.3750 - val_Recall: 0.5854 - val_TP: 120.0000 - val_TN: 0.0000e+00 - val_FN: 85.0000 - val_FP: 200.0000 - val_AUC: 0.3634
# Epoch 19/20
# 41/41 [==============================] - 12s 282ms/step - loss: 0.6932 - Binary_accuracy: 0.4932 - Precision: 0.4926 - Recall: 0.4131 - TP: 335.0000 - TN: 464.0000 - FN: 476.0000 - FP: 345.0000 - AUC: 0.5000 - val_loss: 0.6958 - val_Binary_accuracy: 0.3111 - val_Precision: 0.3865 - val_Recall: 0.6146 - val_TP: 126.0000 - val_TN: 0.0000e+00 - val_FN: 79.0000 - val_FP: 200.0000 - val_AUC: 0.3707
# Epoch 20/20
# 41/41 [==============================] - 11s 276ms/step - loss: 0.6932 - Binary_accuracy: 0.5006 - Precision: 0.5006 - Recall: 1.0000 - TP: 811.0000 - TN: 0.0000e+00 - FN: 0.0000e+00 - FP: 809.0000 - AUC: 0.5000 - val_loss: 0.6958 - val_Binary_accuracy: 0.3111 - val_Precision: 0.3865 - val_Recall: 0.6146 - val_TP: 126.0000 - val_TN: 0.0000e+00 - val_FN: 79.0000 - val_FP: 200.0000 - val_AUC: 0.3683

# %% [markdown]
# ##**VGG16**

# %%
pre_trained_model2 = VGG16(include_top=False, weights='imagenet', input_shape=(114, 144, 3))

for layer in pre_trained_model2.layers:
    layer.trainable = False

pre_trained_model2.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 114, 144, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 114, 144, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 114, 144, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 57, 72, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 57, 72, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 57, 72, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 28, 36, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 28, 36, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 28, 36, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 28, 36, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 14, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 14, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 14, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 14, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 7, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 7, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 7, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 7, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 4, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
last_layer2 = pre_trained_model2.get_layer('block5_pool')
print('last layer output shape:', last_layer2.output_shape)
last_output2 = last_layer2.output

x = layers.Flatten()(last_output2)
x = Dense(512, activation='relu')(x)
x = Dense(256, activation='relu')(x)
x = Dense(128, activation='relu')(x)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
x = Dense(1, activation='sigmoid')(x)


model2 = Model(pre_trained_model2.input, x)
# Out:
# last layer output shape: (None, 3, 4, 512)

# %%
model2.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=[tf.keras.metrics.BinaryAccuracy(name="Binary_accuracy"),
                       tf.keras.metrics.Precision(name='Precision'),
                       tf.keras.metrics.Recall(name='Recall'),
                       tf.keras.metrics.TruePositives(name='TP'),
                       tf.keras.metrics.TrueNegatives(name='TN'),
                       tf.keras.metrics.FalseNegatives(name='FN'),
                       tf.keras.metrics.FalsePositives(name='FP'),
                       tf.keras.metrics.AUC(name='AUC')])

history2 = model2.fit(train_generator, validation_data=(test_images, test_labels), epochs = 20,
            verbose = 1)
# Out:
# Epoch 1/20
# 41/41 [==============================] - 14s 274ms/step - loss: 0.7245 - Binary_accuracy: 0.4981 - Precision: 0.4988 - Recall: 0.4920 - TP: 399.0000 - TN: 408.0000 - FN: 412.0000 - FP: 401.0000 - AUC: 0.4906 - val_loss: 0.6954 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.4325
# Epoch 2/20
# 41/41 [==============================] - 7s 180ms/step - loss: 0.6948 - Binary_accuracy: 0.5080 - Precision: 0.5088 - Recall: 0.5018 - TP: 407.0000 - TN: 416.0000 - FN: 404.0000 - FP: 393.0000 - AUC: 0.5158 - val_loss: 0.7019 - val_Binary_accuracy: 0.4790 - val_Precision: 0.4643 - val_Recall: 0.1902 - val_TP: 39.0000 - val_TN: 155.0000 - val_FN: 166.0000 - val_FP: 45.0000 - val_AUC: 0.2782
# Epoch 3/20
# 41/41 [==============================] - 9s 217ms/step - loss: 0.6957 - Binary_accuracy: 0.4907 - Precision: 0.4915 - Recall: 0.4969 - TP: 403.0000 - TN: 392.0000 - FN: 408.0000 - FP: 417.0000 - AUC: 0.4754 - val_loss: 0.7029 - val_Binary_accuracy: 0.3309 - val_Precision: 0.3969 - val_Recall: 0.6195 - val_TP: 127.0000 - val_TN: 7.0000 - val_FN: 78.0000 - val_FP: 193.0000 - val_AUC: 0.3062
# Epoch 4/20
# 41/41 [==============================] - 8s 188ms/step - loss: 0.6939 - Binary_accuracy: 0.4772 - Precision: 0.4763 - Recall: 0.4464 - TP: 362.0000 - TN: 411.0000 - FN: 449.0000 - FP: 398.0000 - AUC: 0.4881 - val_loss: 0.7009 - val_Binary_accuracy: 0.3358 - val_Precision: 0.3333 - val_Recall: 0.3122 - val_TP: 64.0000 - val_TN: 72.0000 - val_FN: 141.0000 - val_FP: 128.0000 - val_AUC: 0.2810
# Epoch 5/20
# 41/41 [==============================] - 7s 178ms/step - loss: 0.6934 - Binary_accuracy: 0.5006 - Precision: 0.5008 - Recall: 0.7657 - TP: 621.0000 - TN: 190.0000 - FN: 190.0000 - FP: 619.0000 - AUC: 0.4880 - val_loss: 0.6996 - val_Binary_accuracy: 0.4815 - val_Precision: 0.4419 - val_Recall: 0.0927 - val_TP: 19.0000 - val_TN: 176.0000 - val_FN: 186.0000 - val_FP: 24.0000 - val_AUC: 0.2980
# Epoch 6/20
# 41/41 [==============================] - 11s 277ms/step - loss: 0.6934 - Binary_accuracy: 0.4870 - Precision: 0.4872 - Recall: 0.4686 - TP: 380.0000 - TN: 409.0000 - FN: 431.0000 - FP: 400.0000 - AUC: 0.4877 - val_loss: 0.6978 - val_Binary_accuracy: 0.4395 - val_Precision: 0.4068 - val_Recall: 0.2341 - val_TP: 48.0000 - val_TN: 130.0000 - val_FN: 157.0000 - val_FP: 70.0000 - val_AUC: 0.3210
# Epoch 7/20
# 41/41 [==============================] - 13s 305ms/step - loss: 0.6932 - Binary_accuracy: 0.5031 - Precision: 0.5167 - Recall: 0.1147 - TP: 93.0000 - TN: 722.0000 - FN: 718.0000 - FP: 87.0000 - AUC: 0.4973 - val_loss: 0.6968 - val_Binary_accuracy: 0.3580 - val_Precision: 0.4121 - val_Recall: 0.6293 - val_TP: 129.0000 - val_TN: 16.0000 - val_FN: 76.0000 - val_FP: 184.0000 - val_AUC: 0.3650
# Epoch 8/20
# 41/41 [==============================] - 9s 216ms/step - loss: 0.6934 - Binary_accuracy: 0.5006 - Precision: 0.5006 - Recall: 1.0000 - TP: 811.0000 - TN: 0.0000e+00 - FN: 0.0000e+00 - FP: 809.0000 - AUC: 0.4863 - val_loss: 0.6973 - val_Binary_accuracy: 0.3309 - val_Precision: 0.3787 - val_Recall: 0.5024 - val_TP: 103.0000 - val_TN: 31.0000 - val_FN: 102.0000 - val_FP: 169.0000 - val_AUC: 0.3383
# Epoch 9/20
# 41/41 [==============================] - 7s 179ms/step - loss: 0.6932 - Binary_accuracy: 0.5056 - Precision: 0.5033 - Recall: 0.9433 - TP: 765.0000 - TN: 54.0000 - FN: 46.0000 - FP: 755.0000 - AUC: 0.5077 - val_loss: 0.6979 - val_Binary_accuracy: 0.3753 - val_Precision: 0.3667 - val_Recall: 0.3220 - val_TP: 66.0000 - val_TN: 86.0000 - val_FN: 139.0000 - val_FP: 114.0000 - val_AUC: 0.3260
# Epoch 10/20
# 41/41 [==============================] - 9s 211ms/step - loss: 0.6935 - Binary_accuracy: 0.4858 - Precision: 0.4904 - Recall: 0.6893 - TP: 559.0000 - TN: 228.0000 - FN: 252.0000 - FP: 581.0000 - AUC: 0.4759 - val_loss: 0.6970 - val_Binary_accuracy: 0.3160 - val_Precision: 0.3435 - val_Recall: 0.3854 - val_TP: 79.0000 - val_TN: 49.0000 - val_FN: 126.0000 - val_FP: 151.0000 - val_AUC: 0.3227
# Epoch 11/20
# 41/41 [==============================] - 9s 217ms/step - loss: 0.6935 - Binary_accuracy: 0.4870 - Precision: 0.4925 - Recall: 0.8138 - TP: 660.0000 - TN: 129.0000 - FN: 151.0000 - FP: 680.0000 - AUC: 0.4964 - val_loss: 0.6937 - val_Binary_accuracy: 0.4691 - val_Precision: 0.4812 - val_Recall: 0.6244 - val_TP: 128.0000 - val_TN: 62.0000 - val_FN: 77.0000 - val_FP: 138.0000 - val_AUC: 0.4949
# Epoch 12/20
# 41/41 [==============================] - 7s 176ms/step - loss: 0.6933 - Binary_accuracy: 0.4907 - Precision: 0.4917 - Recall: 0.5092 - TP: 413.0000 - TN: 382.0000 - FN: 398.0000 - FP: 427.0000 - AUC: 0.4927 - val_loss: 0.6925 - val_Binary_accuracy: 0.5037 - val_Precision: 0.5075 - val_Recall: 0.6634 - val_TP: 136.0000 - val_TN: 68.0000 - val_FN: 69.0000 - val_FP: 132.0000 - val_AUC: 0.5617
# Epoch 13/20
# 41/41 [==============================] - 10s 235ms/step - loss: 0.6933 - Binary_accuracy: 0.4957 - Precision: 0.4971 - Recall: 0.6252 - TP: 507.0000 - TN: 296.0000 - FN: 304.0000 - FP: 513.0000 - AUC: 0.4907 - val_loss: 0.6920 - val_Binary_accuracy: 0.5333 - val_Precision: 0.5284 - val_Recall: 0.7268 - val_TP: 149.0000 - val_TN: 67.0000 - val_FN: 56.0000 - val_FP: 133.0000 - val_AUC: 0.5814
# Epoch 14/20
# 41/41 [==============================] - 9s 216ms/step - loss: 0.6934 - Binary_accuracy: 0.4994 - Precision: 0.5000 - Recall: 0.8755 - TP: 710.0000 - TN: 99.0000 - FN: 101.0000 - FP: 710.0000 - AUC: 0.4891 - val_loss: 0.6943 - val_Binary_accuracy: 0.4370 - val_Precision: 0.4582 - val_Recall: 0.6146 - val_TP: 126.0000 - val_TN: 51.0000 - val_FN: 79.0000 - val_FP: 149.0000 - val_AUC: 0.4683
# Epoch 15/20
# 41/41 [==============================] - 7s 178ms/step - loss: 0.6933 - Binary_accuracy: 0.4735 - Precision: 0.4737 - Recall: 0.4673 - TP: 379.0000 - TN: 388.0000 - FN: 432.0000 - FP: 421.0000 - AUC: 0.4962 - val_loss: 0.6943 - val_Binary_accuracy: 0.4395 - val_Precision: 0.4580 - val_Recall: 0.5854 - val_TP: 120.0000 - val_TN: 58.0000 - val_FN: 85.0000 - val_FP: 142.0000 - val_AUC: 0.4646
# Epoch 16/20
# 41/41 [==============================] - 7s 180ms/step - loss: 0.6932 - Binary_accuracy: 0.4994 - Precision: 0.5000 - Recall: 0.8508 - TP: 690.0000 - TN: 119.0000 - FN: 121.0000 - FP: 690.0000 - AUC: 0.4965 - val_loss: 0.6953 - val_Binary_accuracy: 0.4247 - val_Precision: 0.4307 - val_Recall: 0.4244 - val_TP: 87.0000 - val_TN: 85.0000 - val_FN: 118.0000 - val_FP: 115.0000 - val_AUC: 0.4166
# Epoch 17/20
# 41/41 [==============================] - 9s 218ms/step - loss: 0.6933 - Binary_accuracy: 0.4759 - Precision: 0.4856 - Recall: 0.7904 - TP: 641.0000 - TN: 130.0000 - FN: 170.0000 - FP: 679.0000 - AUC: 0.4987 - val_loss: 0.6951 - val_Binary_accuracy: 0.4247 - val_Precision: 0.4358 - val_Recall: 0.4634 - val_TP: 95.0000 - val_TN: 77.0000 - val_FN: 110.0000 - val_FP: 123.0000 - val_AUC: 0.4344
# Epoch 18/20
# 41/41 [==============================] - 9s 213ms/step - loss: 0.6933 - Binary_accuracy: 0.4735 - Precision: 0.4767 - Recall: 0.5290 - TP: 429.0000 - TN: 338.0000 - FN: 382.0000 - FP: 471.0000 - AUC: 0.4809 - val_loss: 0.6948 - val_Binary_accuracy: 0.4296 - val_Precision: 0.4425 - val_Recall: 0.4878 - val_TP: 100.0000 - val_TN: 74.0000 - val_FN: 105.0000 - val_FP: 126.0000 - val_AUC: 0.4326
# Epoch 19/20
# 41/41 [==============================] - 9s 215ms/step - loss: 0.6933 - Binary_accuracy: 0.4920 - Precision: 0.4961 - Recall: 0.9420 - TP: 764.0000 - TN: 33.0000 - FN: 47.0000 - FP: 776.0000 - AUC: 0.4932 - val_loss: 0.6947 - val_Binary_accuracy: 0.4222 - val_Precision: 0.4403 - val_Recall: 0.5220 - val_TP: 107.0000 - val_TN: 64.0000 - val_FN: 98.0000 - val_FP: 136.0000 - val_AUC: 0.4412
# Epoch 20/20
# 41/41 [==============================] - 9s 205ms/step - loss: 0.6932 - Binary_accuracy: 0.4944 - Precision: 0.4920 - Recall: 0.3033 - TP: 246.0000 - TN: 555.0000 - FN: 565.0000 - FP: 254.0000 - AUC: 0.4964 - val_loss: 0.6944 - val_Binary_accuracy: 0.4395 - val_Precision: 0.4686 - val_Recall: 0.8000 - val_TP: 164.0000 - val_TN: 14.0000 - val_FN: 41.0000 - val_FP: 186.0000 - val_AUC: 0.4456
