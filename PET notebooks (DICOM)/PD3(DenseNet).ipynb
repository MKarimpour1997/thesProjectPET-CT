# %%
# !pip install pydicom

import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import keras
import cv2
import pickle
import sklearn
import pydicom
import random

from sklearn.metrics import auc, f1_score, roc_curve, recall_score, precision_score, accuracy_score, confusion_matrix
from sklearn import metrics
from google.colab import files
from keras.preprocessing import image
from keras.layers.serialization import activation
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import *
from keras.layers import Dense, GlobalAveragePooling2D, Flatten
from keras.models import Model
from keras import backend as K
from tensorflow.keras import layers, Model
from keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img

tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
# !pip install h5py pyyaml
# Out:
# Collecting pydicom
#   Downloading pydicom-2.4.3-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 13.2 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-2.4.3
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.9.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (6.0.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py) (1.23.5)

# %% [markdown]
# ##**Data Directory**

# %%
base_dir = '/content/drive/MyDrive/PETonlyWholeDataset'

training_set_dir = os.path.join(base_dir, 'trainingSet')
test_set_dir = os.path.join(base_dir, 'testSet')

train_lungCancer_dir = os.path.join(training_set_dir, 'lungCancer')
train_normal_dir = os.path.join(training_set_dir, 'normal')
test_lungCancer_dir = os.path.join(test_set_dir, 'lungCancer')
test_normal_dir = os.path.join(test_set_dir, 'normal')

# %%
train_lungCancer_names = os.listdir(train_lungCancer_dir)
print(train_lungCancer_names[:10])

train_normal_names = os.listdir(train_normal_dir)
print(train_normal_names[:10])
# Out:
# ['00000094 (18).dcm', '00000094 (5).dcm', '00000094 (8).dcm', '00000094 (1).dcm', '00000094 (9).dcm', '00000094 (16).dcm', '00000094 (2).dcm', '00000094 (3).dcm', '00000094 (14).dcm', '00000094 (10).dcm']
# ['00000001 (9).dcm', '00000001 (23).dcm', '00000001 (6).dcm', '00000001 (13).dcm', '00000001 (17).dcm', '00000001 (16).dcm', '00000001 (21).dcm', '00000001 (20).dcm', '00000001 (31).dcm', '00000001 (19).dcm']

# %%
print('total training lungCancer images:', len(os.listdir(train_lungCancer_dir)))
print('total training normal images:', len(os.listdir(train_normal_dir)))
# Out:
# total training lungCancer images: 811
# total training normal images: 809

# %% [markdown]
# ##**Checking Patient Overlap**

# %%
def check_data_leakage(directory1, directory2):
    filenames_dir1 = set(os.listdir(directory1))
    filenames_dir2 = set(os.listdir(directory2))

    common_filenames = filenames_dir1.intersection(filenames_dir2)

    if len(common_filenames) > 0:
        print("Data leakage detected!")
        print("Common image filenames between the directories:", common_filenames)
    else:
        print("No data leakage detected.")

# %%
check_data_leakage(train_lungCancer_dir, test_lungCancer_dir)
check_data_leakage(train_normal_dir, test_normal_dir)
check_data_leakage(train_lungCancer_dir, test_normal_dir)
check_data_leakage(train_normal_dir, test_lungCancer_dir)
# Out:
# No data leakage detected.
# No data leakage detected.
# No data leakage detected.
# No data leakage detected.

# %% [markdown]
# ##**Data Visualization**

# %%
def display_random_dicom_images(directory, num_images=3):
    filenames = os.listdir(directory)
    random_images = random.sample(filenames, num_images)

    for filename in random_images:
        dicom_filepath = os.path.join(directory, filename)
        dicom_data = pydicom.dcmread(dicom_filepath)

        plt.imshow(dicom_data.pixel_array, cmap=plt.cm.bone)
        plt.title(f"Subdirectory: {os.path.basename(directory)}")
        plt.axis('off')
        plt.show()

display_random_dicom_images(test_lungCancer_dir, num_images=3)

# %%
def display_random_dicom_images(directory, num_images=3):
    filenames = os.listdir(directory)
    random_images = random.sample(filenames, num_images)

    for filename in random_images:
        dicom_filepath = os.path.join(directory, filename)
        dicom_data = pydicom.dcmread(dicom_filepath)
        image = dicom_data.pixel_array
        cropped_image = image[30:, :]
        print(cropped_image.shape)

        plt.imshow(cropped_image, cmap=plt.cm.bone)
        plt.title(f"Subdirectory: {os.path.basename(directory)}")
        plt.axis('off')
        plt.show()

display_random_dicom_images(test_lungCancer_dir, num_images=3)
# Out:
# (114, 144)
# (114, 144)
# (114, 144)

# %% [markdown]
# ##Data loading

# %%
def load_and_preprocess_dicom(dcm_path, crop_start):
    dcm_data = pydicom.dcmread(dcm_path)
    image = dcm_data.pixel_array.astype(np.float32) / 255.0  
    cropped_image = image[crop_start:, :]
    image_single_channel = np.expand_dims(cropped_image, axis=-1)
    image_rgb = np.concatenate([image_single_channel] * 3, axis=-1)
    resized_image = tf.image.resize(image_rgb, (114, 144))

    return resized_image

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest')


train_images = np.array([load_and_preprocess_dicom(os.path.join(train_lungCancer_dir, filename), 30) for filename in os.listdir(train_lungCancer_dir) if filename.endswith('.dcm')])
train_labels = np.array([1] * len(train_images))

normal_train_images = np.array([load_and_preprocess_dicom(os.path.join(train_normal_dir, filename), 30) for filename in os.listdir(train_normal_dir) if filename.endswith('.dcm')])
normal_train_labels = np.array([0] * len(normal_train_images))

train_images = np.concatenate((train_images, normal_train_images))
train_labels = np.concatenate((train_labels, normal_train_labels))

train_generator = train_datagen.flow(train_images, train_labels, batch_size=40, shuffle=True)

test_images = np.array([load_and_preprocess_dicom(os.path.join(test_lungCancer_dir, filename), 30) for filename in os.listdir(test_lungCancer_dir) if filename.endswith('.dcm')])
test_labels = np.array([1] * len(test_images))

normal_test_images = np.array([load_and_preprocess_dicom(os.path.join(test_normal_dir, filename), 30) for filename in os.listdir(test_normal_dir) if filename.endswith('.dcm')])
normal_test_labels = np.array([0] * len(normal_test_images))

test_images = np.concatenate((test_images, normal_test_images))
test_labels = np.concatenate((test_labels, normal_test_labels))

# %% [markdown]
# ##**Model defining and compiling**

# %%
pre_trained_model = DenseNet169(include_top=False, weights='imagenet', input_shape=(114, 144, 3))

for layer in pre_trained_model.layers:
    layer.trainable = False

pre_trained_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 [==============================] - 2s 0us/step
# Model: "densenet169"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 114, 144, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 120, 150, 3)  0          ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 57, 72, 64)   9408        ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 57, 72, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 57, 72, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (None, 59, 74, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 29, 36, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 29, 36, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 29, 36, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 29, 36, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 29, 36, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 29, 36, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 29, 36, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 29, 36, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 29, 36, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 29, 36, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 29, 36, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 29, 36, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 29, 36, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 29, 36, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 29, 36, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 29, 36, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 29, 36, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 29, 36, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 29, 36, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 29, 36, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 29, 36, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 29, 36, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 29, 36, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 29, 36, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 29, 36, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 29, 36, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 29, 36, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 29, 36, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 29, 36, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 29, 36, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 29, 36, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 29, 36, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 14, 18, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 14, 18, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 14, 18, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 14, 18, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 14, 18, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 14, 18, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 14, 18, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 14, 18, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 14, 18, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 14, 18, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 14, 18, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 14, 18, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 14, 18, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 14, 18, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 14, 18, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 14, 18, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 14, 18, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 14, 18, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 14, 18, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 14, 18, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 14, 18, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 14, 18, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 14, 18, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 14, 18, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 14, 18, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 14, 18, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 14, 18, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 14, 18, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 14, 18, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 14, 18, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 14, 18, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 14, 18, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 14, 18, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 14, 18, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 14, 18, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 14, 18, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 14, 18, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 14, 18, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 14, 18, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 14, 18, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 14, 18, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 14, 18, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 14, 18, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 14, 18, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 14, 18, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 14, 18, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 14, 18, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 14, 18, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 14, 18, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 14, 18, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 14, 18, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 14, 18, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 14, 18, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 14, 18, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 14, 18, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 14, 18, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 14, 18, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 14, 18, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 14, 18, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 14, 18, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 7, 9, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 7, 9, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 7, 9, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 7, 9, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 7, 9, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 7, 9, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 7, 9, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 7, 9, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 7, 9, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 7, 9, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 7, 9, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 7, 9, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 7, 9, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 7, 9, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 7, 9, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 7, 9, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 7, 9, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 7, 9, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 7, 9, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 7, 9, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 7, 9, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 7, 9, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 7, 9, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 7, 9, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 7, 9, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 7, 9, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 7, 9, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 7, 9, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 7, 9, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 7, 9, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 7, 9, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 7, 9, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 7, 9, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 7, 9, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 7, 9, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 7, 9, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 7, 9, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 7, 9, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 7, 9, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 7, 9, 128)   512         ['conv4_block6_1_conv[0][0]']
#  ization)
# ...
#  ate)                                                             'conv5_block24_2_conv[0][0]']
#
#  conv5_block25_0_bn (BatchNorma  (None, 3, 4, 1408)  5632        ['conv5_block24_concat[0][0]']
#  lization)
#
#  conv5_block25_0_relu (Activati  (None, 3, 4, 1408)  0           ['conv5_block25_0_bn[0][0]']
#  on)
#
#  conv5_block25_1_conv (Conv2D)  (None, 3, 4, 128)    180224      ['conv5_block25_0_relu[0][0]']
#
#  conv5_block25_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block25_1_conv[0][0]']
#  lization)
#
#  conv5_block25_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block25_1_bn[0][0]']
#  on)
#
#  conv5_block25_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block25_1_relu[0][0]']
#
#  conv5_block25_concat (Concaten  (None, 3, 4, 1440)  0           ['conv5_block24_concat[0][0]',
#  ate)                                                             'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 3, 4, 1440)  5760        ['conv5_block25_concat[0][0]']
#  lization)
#
#  conv5_block26_0_relu (Activati  (None, 3, 4, 1440)  0           ['conv5_block26_0_bn[0][0]']
#  on)
#
#  conv5_block26_1_conv (Conv2D)  (None, 3, 4, 128)    184320      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 3, 4, 1472)  0           ['conv5_block25_concat[0][0]',
#  ate)                                                             'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 3, 4, 1472)  5888        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 3, 4, 1472)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 3, 4, 128)    188416      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 3, 4, 1504)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 3, 4, 1504)  6016        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 3, 4, 1504)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 3, 4, 128)    192512      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 3, 4, 1536)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 3, 4, 1536)  6144        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 3, 4, 1536)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 3, 4, 128)    196608      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 3, 4, 1568)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 3, 4, 1568)  6272        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 3, 4, 1568)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 3, 4, 128)    200704      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 3, 4, 1600)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 3, 4, 1600)  6400        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 3, 4, 1600)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 3, 4, 128)    204800      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 3, 4, 1632)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 3, 4, 1632)  6528        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 3, 4, 1632)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 3, 4, 128)    208896      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 3, 4, 1664)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 3, 4, 1664)   6656        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 3, 4, 1664)   0           ['bn[0][0]']
#
# ==================================================================================================
# Total params: 12,642,880
# Trainable params: 0
# Non-trainable params: 12,642,880
# __________________________________________________________________________________________________

# %%
last_layer = pre_trained_model.get_layer('relu')
print('last layer output shape:', last_layer.output_shape)
last_output = last_layer.output

x = GlobalAveragePooling2D()(last_output)
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
x = Dense(1, activation='sigmoid')(x)


model = Model(pre_trained_model.input, x)
# Out:
# last layer output shape: (None, 3, 4, 1664)

# %%
model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=[tf.keras.metrics.BinaryAccuracy(name="Binary_accuracy"),
                       tf.keras.metrics.Precision(name='Precision'),
                       tf.keras.metrics.Recall(name='Recall'),
                       tf.keras.metrics.TruePositives(name='TP'),
                       tf.keras.metrics.TrueNegatives(name='TN'),
                       tf.keras.metrics.FalseNegatives(name='FN'),
                       tf.keras.metrics.FalsePositives(name='FP'),
                       tf.keras.metrics.AUC(name='AUC')])

history = model.fit(train_generator, validation_data=(test_images, test_labels), epochs = 20,
            verbose = 1)
# Out:
# Epoch 1/20
# 41/41 [==============================] - 45s 508ms/step - loss: 0.5660 - Binary_accuracy: 0.7093 - Precision: 0.7648 - Recall: 0.6054 - TP: 491.0000 - TN: 658.0000 - FN: 320.0000 - FP: 151.0000 - AUC: 0.7647 - val_loss: 2.3224 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.4798
# Epoch 2/20
# 41/41 [==============================] - 11s 259ms/step - loss: 0.5245 - Binary_accuracy: 0.7531 - Precision: 0.8586 - Recall: 0.6067 - TP: 492.0000 - TN: 728.0000 - FN: 319.0000 - FP: 81.0000 - AUC: 0.7875 - val_loss: 1.9860 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.4497
# Epoch 3/20
# 41/41 [==============================] - 15s 380ms/step - loss: 0.4885 - Binary_accuracy: 0.7648 - Precision: 0.8308 - Recall: 0.6658 - TP: 540.0000 - TN: 699.0000 - FN: 271.0000 - FP: 110.0000 - AUC: 0.8248 - val_loss: 1.6953 - val_Binary_accuracy: 0.4889 - val_Precision: 0.4975 - val_Recall: 0.9561 - val_TP: 196.0000 - val_TN: 2.0000 - val_FN: 9.0000 - val_FP: 198.0000 - val_AUC: 0.4007
# Epoch 4/20
# 41/41 [==============================] - 10s 238ms/step - loss: 0.4999 - Binary_accuracy: 0.7593 - Precision: 0.8550 - Recall: 0.6252 - TP: 507.0000 - TN: 723.0000 - FN: 304.0000 - FP: 86.0000 - AUC: 0.8016 - val_loss: 1.4508 - val_Binary_accuracy: 0.4123 - val_Precision: 0.4533 - val_Recall: 0.7805 - val_TP: 160.0000 - val_TN: 7.0000 - val_FN: 45.0000 - val_FP: 193.0000 - val_AUC: 0.3681
# Epoch 5/20
# 41/41 [==============================] - 8s 199ms/step - loss: 0.4792 - Binary_accuracy: 0.7895 - Precision: 0.9094 - Recall: 0.6436 - TP: 522.0000 - TN: 757.0000 - FN: 289.0000 - FP: 52.0000 - AUC: 0.8118 - val_loss: 2.4385 - val_Binary_accuracy: 0.5037 - val_Precision: 0.5050 - val_Recall: 0.9902 - val_TP: 203.0000 - val_TN: 1.0000 - val_FN: 2.0000 - val_FP: 199.0000 - val_AUC: 0.4339
# Epoch 6/20
# 41/41 [==============================] - 11s 260ms/step - loss: 0.4792 - Binary_accuracy: 0.7759 - Precision: 0.8771 - Recall: 0.6424 - TP: 521.0000 - TN: 736.0000 - FN: 290.0000 - FP: 73.0000 - AUC: 0.8139 - val_loss: 3.4434 - val_Binary_accuracy: 0.5037 - val_Precision: 0.5050 - val_Recall: 0.9951 - val_TP: 204.0000 - val_TN: 0.0000e+00 - val_FN: 1.0000 - val_FP: 200.0000 - val_AUC: 0.4509
# Epoch 7/20
# 41/41 [==============================] - 10s 236ms/step - loss: 0.4654 - Binary_accuracy: 0.7920 - Precision: 0.8774 - Recall: 0.6794 - TP: 551.0000 - TN: 732.0000 - FN: 260.0000 - FP: 77.0000 - AUC: 0.8322 - val_loss: 2.1830 - val_Binary_accuracy: 0.4716 - val_Precision: 0.4883 - val_Recall: 0.9171 - val_TP: 188.0000 - val_TN: 3.0000 - val_FN: 17.0000 - val_FP: 197.0000 - val_AUC: 0.4494
# Epoch 8/20
# 41/41 [==============================] - 9s 216ms/step - loss: 0.4693 - Binary_accuracy: 0.7870 - Precision: 0.8795 - Recall: 0.6658 - TP: 540.0000 - TN: 735.0000 - FN: 271.0000 - FP: 74.0000 - AUC: 0.8287 - val_loss: 4.6698 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.4829
# Epoch 9/20
# 41/41 [==============================] - 11s 271ms/step - loss: 0.4511 - Binary_accuracy: 0.7969 - Precision: 0.8900 - Recall: 0.6782 - TP: 550.0000 - TN: 741.0000 - FN: 261.0000 - FP: 68.0000 - AUC: 0.8392 - val_loss: 5.8750 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.4854
# Epoch 10/20
# 41/41 [==============================] - 10s 253ms/step - loss: 0.4582 - Binary_accuracy: 0.7920 - Precision: 0.8835 - Recall: 0.6732 - TP: 546.0000 - TN: 737.0000 - FN: 265.0000 - FP: 72.0000 - AUC: 0.8362 - val_loss: 3.4399 - val_Binary_accuracy: 0.4938 - val_Precision: 0.5000 - val_Recall: 0.9707 - val_TP: 199.0000 - val_TN: 1.0000 - val_FN: 6.0000 - val_FP: 199.0000 - val_AUC: 0.5417
# Epoch 11/20
# 41/41 [==============================] - 8s 197ms/step - loss: 0.4487 - Binary_accuracy: 0.7988 - Precision: 0.8956 - Recall: 0.6769 - TP: 549.0000 - TN: 745.0000 - FN: 262.0000 - FP: 64.0000 - AUC: 0.8445 - val_loss: 5.7898 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.4903
# Epoch 12/20
# 41/41 [==============================] - 10s 239ms/step - loss: 0.4413 - Binary_accuracy: 0.8080 - Precision: 0.9167 - Recall: 0.6782 - TP: 550.0000 - TN: 759.0000 - FN: 261.0000 - FP: 50.0000 - AUC: 0.8448 - val_loss: 6.1679 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.4903
# Epoch 13/20
# 41/41 [==============================] - 10s 249ms/step - loss: 0.4568 - Binary_accuracy: 0.7907 - Precision: 0.8770 - Recall: 0.6769 - TP: 549.0000 - TN: 732.0000 - FN: 262.0000 - FP: 77.0000 - AUC: 0.8392 - val_loss: 5.3889 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.4927
# Epoch 14/20
# 41/41 [==============================] - 9s 213ms/step - loss: 0.4398 - Binary_accuracy: 0.8068 - Precision: 0.9136 - Recall: 0.6782 - TP: 550.0000 - TN: 757.0000 - FN: 261.0000 - FP: 52.0000 - AUC: 0.8439 - val_loss: 6.5181 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.4903
# Epoch 15/20
# 41/41 [==============================] - 12s 299ms/step - loss: 0.4615 - Binary_accuracy: 0.7815 - Precision: 0.8656 - Recall: 0.6671 - TP: 541.0000 - TN: 725.0000 - FN: 270.0000 - FP: 84.0000 - AUC: 0.8350 - val_loss: 7.1666 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.5000
# Epoch 16/20
# 41/41 [==============================] - 10s 256ms/step - loss: 0.4343 - Binary_accuracy: 0.8043 - Precision: 0.8958 - Recall: 0.6893 - TP: 559.0000 - TN: 744.0000 - FN: 252.0000 - FP: 65.0000 - AUC: 0.8574 - val_loss: 5.6675 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.4926
# Epoch 17/20
# 41/41 [==============================] - 15s 374ms/step - loss: 0.4412 - Binary_accuracy: 0.7907 - Precision: 0.8844 - Recall: 0.6695 - TP: 543.0000 - TN: 738.0000 - FN: 268.0000 - FP: 71.0000 - AUC: 0.8521 - val_loss: 5.5609 - val_Binary_accuracy: 0.4988 - val_Precision: 0.5025 - val_Recall: 0.9854 - val_TP: 202.0000 - val_TN: 0.0000e+00 - val_FN: 3.0000 - val_FP: 200.0000 - val_AUC: 0.4903
# Epoch 18/20
# 41/41 [==============================] - 11s 264ms/step - loss: 0.4501 - Binary_accuracy: 0.7944 - Precision: 0.8918 - Recall: 0.6708 - TP: 544.0000 - TN: 743.0000 - FN: 267.0000 - FP: 66.0000 - AUC: 0.8414 - val_loss: 6.3119 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.4928
# Epoch 19/20
# 41/41 [==============================] - 21s 522ms/step - loss: 0.4356 - Binary_accuracy: 0.8062 - Precision: 0.8976 - Recall: 0.6917 - TP: 561.0000 - TN: 745.0000 - FN: 250.0000 - FP: 64.0000 - AUC: 0.8555 - val_loss: 6.6291 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.4928
# Epoch 20/20
# 41/41 [==============================] - 10s 232ms/step - loss: 0.4364 - Binary_accuracy: 0.7994 - Precision: 0.8821 - Recall: 0.6917 - TP: 561.0000 - TN: 734.0000 - FN: 250.0000 - FP: 75.0000 - AUC: 0.8528 - val_loss: 7.6649 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.5001

# %% [markdown]
# ##**Defining DenseNet201 model**

# %%
pre_trained_model2 = DenseNet201(include_top=False, weights='imagenet', input_shape=(114, 144, 3))

for layer in pre_trained_model2.layers:
    layer.trainable = False

pre_trained_model2.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 3s 0us/step
# Model: "densenet201"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 114, 144, 3  0           []
#                                 )]
#
#  zero_padding2d_2 (ZeroPadding2  (None, 120, 150, 3)  0          ['input_2[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 57, 72, 64)   9408        ['zero_padding2d_2[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 57, 72, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 57, 72, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 59, 74, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 29, 36, 64)   0           ['zero_padding2d_3[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 29, 36, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 29, 36, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 29, 36, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 29, 36, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 29, 36, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 29, 36, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 29, 36, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 29, 36, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 29, 36, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 29, 36, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 29, 36, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 29, 36, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 29, 36, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 29, 36, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 29, 36, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 29, 36, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 29, 36, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 29, 36, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 29, 36, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 29, 36, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 29, 36, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 29, 36, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 29, 36, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 29, 36, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 29, 36, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 29, 36, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 29, 36, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 29, 36, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 29, 36, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 29, 36, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 29, 36, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 14, 18, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 14, 18, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 14, 18, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 14, 18, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 14, 18, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 14, 18, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 14, 18, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 14, 18, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 14, 18, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 14, 18, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 14, 18, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 14, 18, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 14, 18, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 14, 18, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 14, 18, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 14, 18, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 14, 18, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 14, 18, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 14, 18, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 14, 18, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 14, 18, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 14, 18, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 14, 18, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 14, 18, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 14, 18, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 14, 18, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 14, 18, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 14, 18, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 14, 18, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 14, 18, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 14, 18, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 14, 18, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 14, 18, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 14, 18, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 14, 18, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 14, 18, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 14, 18, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 14, 18, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 14, 18, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 14, 18, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 14, 18, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 14, 18, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 14, 18, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 14, 18, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 14, 18, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 14, 18, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 14, 18, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 14, 18, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 14, 18, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 14, 18, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 14, 18, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 14, 18, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 14, 18, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 14, 18, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 14, 18, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 14, 18, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 14, 18, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 14, 18, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 14, 18, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 14, 18, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 7, 9, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 7, 9, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 7, 9, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 7, 9, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 7, 9, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 7, 9, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 7, 9, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 7, 9, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 7, 9, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 7, 9, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 7, 9, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 7, 9, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 7, 9, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 7, 9, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 7, 9, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 7, 9, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 7, 9, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 7, 9, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 7, 9, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 7, 9, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 7, 9, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 7, 9, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 7, 9, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 7, 9, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 7, 9, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 7, 9, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 7, 9, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 7, 9, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 7, 9, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 7, 9, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 7, 9, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 7, 9, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 7, 9, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 7, 9, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 7, 9, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 7, 9, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 7, 9, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 7, 9, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 7, 9, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 7, 9, 128)   512         ['conv4_block6_1_conv[0][0]']
# ...
#  ate)                                                             'conv5_block24_2_conv[0][0]']
#
#  conv5_block25_0_bn (BatchNorma  (None, 3, 4, 1664)  6656        ['conv5_block24_concat[0][0]']
#  lization)
#
#  conv5_block25_0_relu (Activati  (None, 3, 4, 1664)  0           ['conv5_block25_0_bn[0][0]']
#  on)
#
#  conv5_block25_1_conv (Conv2D)  (None, 3, 4, 128)    212992      ['conv5_block25_0_relu[0][0]']
#
#  conv5_block25_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block25_1_conv[0][0]']
#  lization)
#
#  conv5_block25_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block25_1_bn[0][0]']
#  on)
#
#  conv5_block25_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block25_1_relu[0][0]']
#
#  conv5_block25_concat (Concaten  (None, 3, 4, 1696)  0           ['conv5_block24_concat[0][0]',
#  ate)                                                             'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 3, 4, 1696)  6784        ['conv5_block25_concat[0][0]']
#  lization)
#
#  conv5_block26_0_relu (Activati  (None, 3, 4, 1696)  0           ['conv5_block26_0_bn[0][0]']
#  on)
#
#  conv5_block26_1_conv (Conv2D)  (None, 3, 4, 128)    217088      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 3, 4, 1728)  0           ['conv5_block25_concat[0][0]',
#  ate)                                                             'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 3, 4, 1728)  6912        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 3, 4, 1728)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 3, 4, 128)    221184      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 3, 4, 1760)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 3, 4, 1760)  7040        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 3, 4, 1760)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 3, 4, 128)    225280      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 3, 4, 1792)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 3, 4, 1792)  7168        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 3, 4, 1792)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 3, 4, 128)    229376      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 3, 4, 1824)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 3, 4, 1824)  7296        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 3, 4, 1824)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 3, 4, 128)    233472      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 3, 4, 1856)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 3, 4, 1856)  7424        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 3, 4, 1856)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 3, 4, 128)    237568      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 3, 4, 1888)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 3, 4, 1888)  7552        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 3, 4, 1888)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 3, 4, 128)    241664      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 3, 4, 1920)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 3, 4, 1920)   7680        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 3, 4, 1920)   0           ['bn[0][0]']
#
# ==================================================================================================
# Total params: 18,321,984
# Trainable params: 0
# Non-trainable params: 18,321,984
# __________________________________________________________________________________________________

# %%
last_layer2 = pre_trained_model2.get_layer('relu')
print('last layer output shape:', last_layer2.output_shape)
last_output2 = last_layer2.output

x = GlobalAveragePooling2D()(last_output2)
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
x = Dense(1, activation='sigmoid')(x)


model2 = Model(pre_trained_model2.input, x)
# Out:
# last layer output shape: (None, 3, 4, 1920)

# %%
model2.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=[tf.keras.metrics.BinaryAccuracy(name="Binary_accuracy"),
                       tf.keras.metrics.Precision(name='Precision'),
                       tf.keras.metrics.Recall(name='Recall'),
                       tf.keras.metrics.TruePositives(name='TP'),
                       tf.keras.metrics.TrueNegatives(name='TN'),
                       tf.keras.metrics.FalseNegatives(name='FN'),
                       tf.keras.metrics.FalsePositives(name='FP'),
                       tf.keras.metrics.AUC(name='AUC')])

history2 = model2.fit(train_generator, validation_data=(test_images, test_labels), epochs = 20,
            verbose = 1)
# Out:
# Epoch 1/20
# 41/41 [==============================] - 37s 472ms/step - loss: 0.5580 - Binary_accuracy: 0.7160 - Precision: 0.8063 - Recall: 0.5697 - TP: 462.0000 - TN: 698.0000 - FN: 349.0000 - FP: 111.0000 - AUC: 0.7637 - val_loss: 3.4610 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.5075
# Epoch 2/20
# 41/41 [==============================] - 8s 204ms/step - loss: 0.5068 - Binary_accuracy: 0.7599 - Precision: 0.8517 - Recall: 0.6301 - TP: 511.0000 - TN: 720.0000 - FN: 300.0000 - FP: 89.0000 - AUC: 0.8103 - val_loss: 1.5287 - val_Binary_accuracy: 0.4272 - val_Precision: 0.4634 - val_Recall: 0.8341 - val_TP: 171.0000 - val_TN: 2.0000 - val_FN: 34.0000 - val_FP: 198.0000 - val_AUC: 0.3347
# Epoch 3/20
# 41/41 [==============================] - 11s 276ms/step - loss: 0.4906 - Binary_accuracy: 0.7759 - Precision: 0.8660 - Recall: 0.6535 - TP: 530.0000 - TN: 727.0000 - FN: 281.0000 - FP: 82.0000 - AUC: 0.8154 - val_loss: 1.3864 - val_Binary_accuracy: 0.3926 - val_Precision: 0.4392 - val_Recall: 0.7220 - val_TP: 148.0000 - val_TN: 11.0000 - val_FN: 57.0000 - val_FP: 189.0000 - val_AUC: 0.3452
# Epoch 4/20
# 41/41 [==============================] - 10s 232ms/step - loss: 0.4737 - Binary_accuracy: 0.7796 - Precision: 0.8536 - Recall: 0.6757 - TP: 548.0000 - TN: 715.0000 - FN: 263.0000 - FP: 94.0000 - AUC: 0.8329 - val_loss: 2.1598 - val_Binary_accuracy: 0.4691 - val_Precision: 0.4870 - val_Recall: 0.9171 - val_TP: 188.0000 - val_TN: 2.0000 - val_FN: 17.0000 - val_FP: 198.0000 - val_AUC: 0.4275
# Epoch 5/20
# 41/41 [==============================] - 10s 251ms/step - loss: 0.4639 - Binary_accuracy: 0.7895 - Precision: 0.8803 - Recall: 0.6708 - TP: 544.0000 - TN: 735.0000 - FN: 267.0000 - FP: 74.0000 - AUC: 0.8341 - val_loss: 1.8416 - val_Binary_accuracy: 0.3580 - val_Precision: 0.3529 - val_Recall: 0.3220 - val_TP: 66.0000 - val_TN: 79.0000 - val_FN: 139.0000 - val_FP: 121.0000 - val_AUC: 0.2966
# Epoch 6/20
# 41/41 [==============================] - 8s 207ms/step - loss: 0.4604 - Binary_accuracy: 0.7889 - Precision: 0.8764 - Recall: 0.6732 - TP: 546.0000 - TN: 732.0000 - FN: 265.0000 - FP: 77.0000 - AUC: 0.8435 - val_loss: 2.1147 - val_Binary_accuracy: 0.4444 - val_Precision: 0.4728 - val_Recall: 0.8488 - val_TP: 174.0000 - val_TN: 6.0000 - val_FN: 31.0000 - val_FP: 194.0000 - val_AUC: 0.4093
# Epoch 7/20
# 41/41 [==============================] - 9s 215ms/step - loss: 0.4616 - Binary_accuracy: 0.7870 - Precision: 0.8722 - Recall: 0.6732 - TP: 546.0000 - TN: 729.0000 - FN: 265.0000 - FP: 80.0000 - AUC: 0.8354 - val_loss: 2.3642 - val_Binary_accuracy: 0.4148 - val_Precision: 0.4524 - val_Recall: 0.7415 - val_TP: 152.0000 - val_TN: 16.0000 - val_FN: 53.0000 - val_FP: 184.0000 - val_AUC: 0.3645
# Epoch 8/20
# 41/41 [==============================] - 11s 259ms/step - loss: 0.4477 - Binary_accuracy: 0.8019 - Precision: 0.8914 - Recall: 0.6880 - TP: 558.0000 - TN: 741.0000 - FN: 253.0000 - FP: 68.0000 - AUC: 0.8491 - val_loss: 2.2557 - val_Binary_accuracy: 0.3852 - val_Precision: 0.3791 - val_Recall: 0.3366 - val_TP: 69.0000 - val_TN: 87.0000 - val_FN: 136.0000 - val_FP: 113.0000 - val_AUC: 0.3128
# Epoch 9/20
# 41/41 [==============================] - 13s 307ms/step - loss: 0.4433 - Binary_accuracy: 0.8056 - Precision: 0.8863 - Recall: 0.7016 - TP: 569.0000 - TN: 736.0000 - FN: 242.0000 - FP: 73.0000 - AUC: 0.8563 - val_loss: 2.2647 - val_Binary_accuracy: 0.3679 - val_Precision: 0.3896 - val_Recall: 0.4390 - val_TP: 90.0000 - val_TN: 59.0000 - val_FN: 115.0000 - val_FP: 141.0000 - val_AUC: 0.3194
# Epoch 10/20
# 41/41 [==============================] - 9s 216ms/step - loss: 0.4373 - Binary_accuracy: 0.7944 - Precision: 0.8880 - Recall: 0.6745 - TP: 547.0000 - TN: 740.0000 - FN: 264.0000 - FP: 69.0000 - AUC: 0.8539 - val_loss: 3.5066 - val_Binary_accuracy: 0.4198 - val_Precision: 0.4559 - val_Recall: 0.7561 - val_TP: 155.0000 - val_TN: 15.0000 - val_FN: 50.0000 - val_FP: 185.0000 - val_AUC: 0.3606
# Epoch 11/20
# 41/41 [==============================] - 10s 238ms/step - loss: 0.4366 - Binary_accuracy: 0.7975 - Precision: 0.8876 - Recall: 0.6819 - TP: 553.0000 - TN: 739.0000 - FN: 258.0000 - FP: 70.0000 - AUC: 0.8595 - val_loss: 4.0242 - val_Binary_accuracy: 0.4469 - val_Precision: 0.4738 - val_Recall: 0.8390 - val_TP: 172.0000 - val_TN: 9.0000 - val_FN: 33.0000 - val_FP: 191.0000 - val_AUC: 0.3617
# Epoch 12/20
# 41/41 [==============================] - 12s 302ms/step - loss: 0.4290 - Binary_accuracy: 0.8025 - Precision: 0.8830 - Recall: 0.6979 - TP: 566.0000 - TN: 734.0000 - FN: 245.0000 - FP: 75.0000 - AUC: 0.8664 - val_loss: 3.8571 - val_Binary_accuracy: 0.4049 - val_Precision: 0.4444 - val_Recall: 0.7024 - val_TP: 144.0000 - val_TN: 20.0000 - val_FN: 61.0000 - val_FP: 180.0000 - val_AUC: 0.3673
# Epoch 13/20
# 41/41 [==============================] - 9s 214ms/step - loss: 0.4246 - Binary_accuracy: 0.8099 - Precision: 0.8936 - Recall: 0.7041 - TP: 571.0000 - TN: 741.0000 - FN: 240.0000 - FP: 68.0000 - AUC: 0.8587 - val_loss: 4.0083 - val_Binary_accuracy: 0.4346 - val_Precision: 0.4655 - val_Recall: 0.7902 - val_TP: 162.0000 - val_TN: 14.0000 - val_FN: 43.0000 - val_FP: 186.0000 - val_AUC: 0.3850
# Epoch 14/20
# 41/41 [==============================] - 9s 222ms/step - loss: 0.4191 - Binary_accuracy: 0.8154 - Precision: 0.9116 - Recall: 0.6991 - TP: 567.0000 - TN: 754.0000 - FN: 244.0000 - FP: 55.0000 - AUC: 0.8675 - val_loss: 4.9316 - val_Binary_accuracy: 0.4617 - val_Precision: 0.4827 - val_Recall: 0.8829 - val_TP: 181.0000 - val_TN: 6.0000 - val_FN: 24.0000 - val_FP: 194.0000 - val_AUC: 0.4279
# Epoch 15/20
# 41/41 [==============================] - 12s 272ms/step - loss: 0.4174 - Binary_accuracy: 0.8080 - Precision: 0.8776 - Recall: 0.7164 - TP: 581.0000 - TN: 728.0000 - FN: 230.0000 - FP: 81.0000 - AUC: 0.8752 - val_loss: 3.9011 - val_Binary_accuracy: 0.4296 - val_Precision: 0.4611 - val_Recall: 0.7512 - val_TP: 154.0000 - val_TN: 20.0000 - val_FN: 51.0000 - val_FP: 180.0000 - val_AUC: 0.4294
# Epoch 16/20
# 41/41 [==============================] - 10s 256ms/step - loss: 0.4261 - Binary_accuracy: 0.7957 - Precision: 0.8571 - Recall: 0.7102 - TP: 576.0000 - TN: 713.0000 - FN: 235.0000 - FP: 96.0000 - AUC: 0.8666 - val_loss: 3.8322 - val_Binary_accuracy: 0.4099 - val_Precision: 0.4441 - val_Recall: 0.6585 - val_TP: 135.0000 - val_TN: 31.0000 - val_FN: 70.0000 - val_FP: 169.0000 - val_AUC: 0.4010
# Epoch 17/20
# 41/41 [==============================] - 10s 255ms/step - loss: 0.4059 - Binary_accuracy: 0.8167 - Precision: 0.9159 - Recall: 0.6979 - TP: 566.0000 - TN: 757.0000 - FN: 245.0000 - FP: 52.0000 - AUC: 0.8803 - val_loss: 3.6248 - val_Binary_accuracy: 0.4642 - val_Precision: 0.4784 - val_Recall: 0.6488 - val_TP: 133.0000 - val_TN: 55.0000 - val_FN: 72.0000 - val_FP: 145.0000 - val_AUC: 0.4600
# Epoch 18/20
# 41/41 [==============================] - 11s 266ms/step - loss: 0.4216 - Binary_accuracy: 0.8062 - Precision: 0.8963 - Recall: 0.6930 - TP: 562.0000 - TN: 744.0000 - FN: 249.0000 - FP: 65.0000 - AUC: 0.8648 - val_loss: 3.2690 - val_Binary_accuracy: 0.4543 - val_Precision: 0.4636 - val_Recall: 0.4976 - val_TP: 102.0000 - val_TN: 82.0000 - val_FN: 103.0000 - val_FP: 118.0000 - val_AUC: 0.4323
# Epoch 19/20
# 41/41 [==============================] - 10s 256ms/step - loss: 0.3976 - Binary_accuracy: 0.8111 - Precision: 0.8843 - Recall: 0.7164 - TP: 581.0000 - TN: 733.0000 - FN: 230.0000 - FP: 76.0000 - AUC: 0.8821 - val_loss: 3.6326 - val_Binary_accuracy: 0.4370 - val_Precision: 0.4549 - val_Recall: 0.5659 - val_TP: 116.0000 - val_TN: 61.0000 - val_FN: 89.0000 - val_FP: 139.0000 - val_AUC: 0.4173
# Epoch 20/20
# 41/41 [==============================] - 8s 204ms/step - loss: 0.4195 - Binary_accuracy: 0.8142 - Precision: 0.9087 - Recall: 0.6991 - TP: 567.0000 - TN: 752.0000 - FN: 244.0000 - FP: 57.0000 - AUC: 0.8656 - val_loss: 4.4995 - val_Binary_accuracy: 0.4173 - val_Precision: 0.4505 - val_Recall: 0.6878 - val_TP: 141.0000 - val_TN: 28.0000 - val_FN: 64.0000 - val_FP: 172.0000 - val_AUC: 0.3958

# %% [markdown]
# ##**DenseNet201**

# %%
pre_trained_model3 = DenseNet201(include_top=False, weights='imagenet', input_shape=(114, 144, 3))

for layer in pre_trained_model3.layers:
    layer.trainable = False

pre_trained_model3.summary()
# Out:
# Model: "densenet201"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 114, 144, 3  0           []
#                                 )]
#
#  zero_padding2d_4 (ZeroPadding2  (None, 120, 150, 3)  0          ['input_3[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 57, 72, 64)   9408        ['zero_padding2d_4[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 57, 72, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 57, 72, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_5 (ZeroPadding2  (None, 59, 74, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 29, 36, 64)   0           ['zero_padding2d_5[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 29, 36, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 29, 36, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 29, 36, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 29, 36, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 29, 36, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 29, 36, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 29, 36, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 29, 36, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 29, 36, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 29, 36, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 29, 36, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 29, 36, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 29, 36, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 29, 36, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 29, 36, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 29, 36, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 29, 36, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 29, 36, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 29, 36, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 29, 36, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 29, 36, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 29, 36, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 29, 36, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 29, 36, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 29, 36, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 29, 36, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 29, 36, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 29, 36, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 29, 36, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 29, 36, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 29, 36, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 29, 36, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 29, 36, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 14, 18, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 14, 18, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 14, 18, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 14, 18, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 14, 18, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 14, 18, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 14, 18, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 14, 18, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 14, 18, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 14, 18, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 14, 18, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 14, 18, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 14, 18, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 14, 18, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 14, 18, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 14, 18, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 14, 18, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 14, 18, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 14, 18, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 14, 18, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 14, 18, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 14, 18, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 14, 18, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 14, 18, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 14, 18, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 14, 18, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 14, 18, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 14, 18, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 14, 18, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 14, 18, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 14, 18, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 14, 18, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 14, 18, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 14, 18, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 14, 18, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 14, 18, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 14, 18, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 14, 18, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 14, 18, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 14, 18, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 14, 18, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 14, 18, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 14, 18, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 14, 18, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 14, 18, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 14, 18, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 14, 18, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 14, 18, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 14, 18, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 14, 18, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 14, 18, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 14, 18, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 14, 18, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 14, 18, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 14, 18, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 14, 18, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 14, 18, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 14, 18, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 14, 18, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 14, 18, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 14, 18, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 14, 18, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 14, 18, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 7, 9, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 7, 9, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 7, 9, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 7, 9, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 7, 9, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 7, 9, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 7, 9, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 7, 9, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 7, 9, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 7, 9, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 7, 9, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 7, 9, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 7, 9, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 7, 9, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 7, 9, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 7, 9, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 7, 9, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 7, 9, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 7, 9, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 7, 9, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 7, 9, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 7, 9, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 7, 9, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 7, 9, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 7, 9, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 7, 9, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 7, 9, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 7, 9, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 7, 9, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 7, 9, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 7, 9, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 7, 9, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 7, 9, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 7, 9, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 7, 9, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 7, 9, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 7, 9, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 7, 9, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 7, 9, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 7, 9, 128)   512         ['conv4_block6_1_conv[0][0]']
#  ization)
#
# ...
#  ate)                                                             'conv5_block24_2_conv[0][0]']
#
#  conv5_block25_0_bn (BatchNorma  (None, 3, 4, 1664)  6656        ['conv5_block24_concat[0][0]']
#  lization)
#
#  conv5_block25_0_relu (Activati  (None, 3, 4, 1664)  0           ['conv5_block25_0_bn[0][0]']
#  on)
#
#  conv5_block25_1_conv (Conv2D)  (None, 3, 4, 128)    212992      ['conv5_block25_0_relu[0][0]']
#
#  conv5_block25_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block25_1_conv[0][0]']
#  lization)
#
#  conv5_block25_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block25_1_bn[0][0]']
#  on)
#
#  conv5_block25_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block25_1_relu[0][0]']
#
#  conv5_block25_concat (Concaten  (None, 3, 4, 1696)  0           ['conv5_block24_concat[0][0]',
#  ate)                                                             'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 3, 4, 1696)  6784        ['conv5_block25_concat[0][0]']
#  lization)
#
#  conv5_block26_0_relu (Activati  (None, 3, 4, 1696)  0           ['conv5_block26_0_bn[0][0]']
#  on)
#
#  conv5_block26_1_conv (Conv2D)  (None, 3, 4, 128)    217088      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 3, 4, 1728)  0           ['conv5_block25_concat[0][0]',
#  ate)                                                             'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 3, 4, 1728)  6912        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 3, 4, 1728)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 3, 4, 128)    221184      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 3, 4, 1760)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 3, 4, 1760)  7040        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 3, 4, 1760)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 3, 4, 128)    225280      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 3, 4, 1792)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 3, 4, 1792)  7168        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 3, 4, 1792)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 3, 4, 128)    229376      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 3, 4, 1824)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 3, 4, 1824)  7296        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 3, 4, 1824)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 3, 4, 128)    233472      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 3, 4, 1856)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 3, 4, 1856)  7424        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 3, 4, 1856)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 3, 4, 128)    237568      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 3, 4, 1888)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 3, 4, 1888)  7552        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 3, 4, 1888)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 3, 4, 128)    241664      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 3, 4, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 3, 4, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 3, 4, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 3, 4, 1920)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 3, 4, 1920)   7680        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 3, 4, 1920)   0           ['bn[0][0]']
#
# ==================================================================================================
# Total params: 18,321,984
# Trainable params: 0
# Non-trainable params: 18,321,984
# __________________________________________________________________________________________________

# %%
last_layer3 = pre_trained_model3.get_layer('relu')
print('last layer output shape:', last_layer3.output_shape)
last_output3 = last_layer3.output

x = layers.Flatten()(last_output3)
x = Dense(128, activation='relu')(x)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
x = Dense(1, activation='sigmoid')(x)


model3 = Model(pre_trained_model3.input, x)
# Out:
# last layer output shape: (None, 3, 4, 1920)

# %%
model3.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=[tf.keras.metrics.BinaryAccuracy(name="Binary_accuracy"),
                       tf.keras.metrics.Precision(name='Precision'),
                       tf.keras.metrics.Recall(name='Recall'),
                       tf.keras.metrics.TruePositives(name='TP'),
                       tf.keras.metrics.TrueNegatives(name='TN'),
                       tf.keras.metrics.FalseNegatives(name='FN'),
                       tf.keras.metrics.FalsePositives(name='FP'),
                       tf.keras.metrics.AUC(name='AUC')])

history3 = model3.fit(train_generator, validation_data=(test_images, test_labels), epochs = 20,
            verbose = 1)
# Out:
# Epoch 1/20
# 41/41 [==============================] - 33s 397ms/step - loss: 0.6155 - Binary_accuracy: 0.7111 - Precision: 0.7454 - Recall: 0.6424 - TP: 521.0000 - TN: 631.0000 - FN: 290.0000 - FP: 178.0000 - AUC: 0.7475 - val_loss: 0.7431 - val_Binary_accuracy: 0.4716 - val_Precision: 0.4880 - val_Recall: 0.8927 - val_TP: 183.0000 - val_TN: 8.0000 - val_FN: 22.0000 - val_FP: 192.0000 - val_AUC: 0.4978
# Epoch 2/20
# 41/41 [==============================] - 10s 240ms/step - loss: 0.5307 - Binary_accuracy: 0.7216 - Precision: 0.7671 - Recall: 0.6375 - TP: 517.0000 - TN: 652.0000 - FN: 294.0000 - FP: 157.0000 - AUC: 0.7924 - val_loss: 1.7459 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.5178
# Epoch 3/20
# 41/41 [==============================] - 8s 203ms/step - loss: 0.4897 - Binary_accuracy: 0.7599 - Precision: 0.8328 - Recall: 0.6510 - TP: 528.0000 - TN: 703.0000 - FN: 283.0000 - FP: 106.0000 - AUC: 0.8168 - val_loss: 1.6829 - val_Binary_accuracy: 0.4988 - val_Precision: 1.0000 - val_Recall: 0.0098 - val_TP: 2.0000 - val_TN: 200.0000 - val_FN: 203.0000 - val_FP: 0.0000e+00 - val_AUC: 0.3118
# Epoch 4/20
# 41/41 [==============================] - 11s 271ms/step - loss: 0.4871 - Binary_accuracy: 0.7698 - Precision: 0.8380 - Recall: 0.6695 - TP: 543.0000 - TN: 704.0000 - FN: 268.0000 - FP: 105.0000 - AUC: 0.8148 - val_loss: 1.7789 - val_Binary_accuracy: 0.4988 - val_Precision: 0.5025 - val_Recall: 0.9854 - val_TP: 202.0000 - val_TN: 0.0000e+00 - val_FN: 3.0000 - val_FP: 200.0000 - val_AUC: 0.5697
# Epoch 5/20
# 41/41 [==============================] - 11s 271ms/step - loss: 0.4807 - Binary_accuracy: 0.7914 - Precision: 0.8760 - Recall: 0.6794 - TP: 551.0000 - TN: 731.0000 - FN: 260.0000 - FP: 78.0000 - AUC: 0.8298 - val_loss: 1.2636 - val_Binary_accuracy: 0.4395 - val_Precision: 0.4329 - val_Recall: 0.3463 - val_TP: 71.0000 - val_TN: 107.0000 - val_FN: 134.0000 - val_FP: 93.0000 - val_AUC: 0.3799
# Epoch 6/20
# 41/41 [==============================] - 10s 236ms/step - loss: 0.4664 - Binary_accuracy: 0.7932 - Precision: 0.8730 - Recall: 0.6868 - TP: 557.0000 - TN: 728.0000 - FN: 254.0000 - FP: 81.0000 - AUC: 0.8421 - val_loss: 0.7944 - val_Binary_accuracy: 0.5333 - val_Precision: 0.5392 - val_Recall: 0.5366 - val_TP: 110.0000 - val_TN: 106.0000 - val_FN: 95.0000 - val_FP: 94.0000 - val_AUC: 0.5236
# Epoch 7/20
# 41/41 [==============================] - 11s 254ms/step - loss: 0.4511 - Binary_accuracy: 0.7981 - Precision: 0.8854 - Recall: 0.6856 - TP: 556.0000 - TN: 737.0000 - FN: 255.0000 - FP: 72.0000 - AUC: 0.8493 - val_loss: 1.1878 - val_Binary_accuracy: 0.5259 - val_Precision: 0.5684 - val_Recall: 0.2634 - val_TP: 54.0000 - val_TN: 159.0000 - val_FN: 151.0000 - val_FP: 41.0000 - val_AUC: 0.4070
# Epoch 8/20
# 41/41 [==============================] - 10s 252ms/step - loss: 0.4550 - Binary_accuracy: 0.7944 - Precision: 0.8818 - Recall: 0.6806 - TP: 552.0000 - TN: 735.0000 - FN: 259.0000 - FP: 74.0000 - AUC: 0.8405 - val_loss: 1.0799 - val_Binary_accuracy: 0.4321 - val_Precision: 0.4590 - val_Recall: 0.6829 - val_TP: 140.0000 - val_TN: 35.0000 - val_FN: 65.0000 - val_FP: 165.0000 - val_AUC: 0.4586
# Epoch 9/20
# 41/41 [==============================] - 9s 218ms/step - loss: 0.4507 - Binary_accuracy: 0.7994 - Precision: 0.8727 - Recall: 0.7016 - TP: 569.0000 - TN: 726.0000 - FN: 242.0000 - FP: 83.0000 - AUC: 0.8562 - val_loss: 1.5125 - val_Binary_accuracy: 0.4765 - val_Precision: 0.4909 - val_Recall: 0.9220 - val_TP: 189.0000 - val_TN: 4.0000 - val_FN: 16.0000 - val_FP: 196.0000 - val_AUC: 0.6702
# Epoch 10/20
# 41/41 [==============================] - 9s 213ms/step - loss: 0.4423 - Binary_accuracy: 0.7938 - Precision: 0.8744 - Recall: 0.6868 - TP: 557.0000 - TN: 729.0000 - FN: 254.0000 - FP: 80.0000 - AUC: 0.8516 - val_loss: 1.2036 - val_Binary_accuracy: 0.4593 - val_Precision: 0.4777 - val_Recall: 0.7317 - val_TP: 150.0000 - val_TN: 36.0000 - val_FN: 55.0000 - val_FP: 164.0000 - val_AUC: 0.5487
# Epoch 11/20
# 41/41 [==============================] - 12s 302ms/step - loss: 0.4359 - Binary_accuracy: 0.7926 - Precision: 0.8752 - Recall: 0.6831 - TP: 554.0000 - TN: 730.0000 - FN: 257.0000 - FP: 79.0000 - AUC: 0.8553 - val_loss: 1.4444 - val_Binary_accuracy: 0.4494 - val_Precision: 0.4531 - val_Recall: 0.4244 - val_TP: 87.0000 - val_TN: 95.0000 - val_FN: 118.0000 - val_FP: 105.0000 - val_AUC: 0.4174
# Epoch 12/20
# 41/41 [==============================] - 11s 267ms/step - loss: 0.4194 - Binary_accuracy: 0.8198 - Precision: 0.9332 - Recall: 0.6893 - TP: 559.0000 - TN: 769.0000 - FN: 252.0000 - FP: 40.0000 - AUC: 0.8699 - val_loss: 2.8670 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.5321
# Epoch 13/20
# 41/41 [==============================] - 9s 226ms/step - loss: 0.4238 - Binary_accuracy: 0.8062 - Precision: 0.8817 - Recall: 0.7078 - TP: 574.0000 - TN: 732.0000 - FN: 237.0000 - FP: 77.0000 - AUC: 0.8722 - val_loss: 4.6816 - val_Binary_accuracy: 0.5037 - val_Precision: 0.5050 - val_Recall: 0.9951 - val_TP: 204.0000 - val_TN: 0.0000e+00 - val_FN: 1.0000 - val_FP: 200.0000 - val_AUC: 0.4389
# Epoch 14/20
# 41/41 [==============================] - 9s 219ms/step - loss: 0.4113 - Binary_accuracy: 0.8086 - Precision: 0.8983 - Recall: 0.6967 - TP: 565.0000 - TN: 745.0000 - FN: 246.0000 - FP: 64.0000 - AUC: 0.8730 - val_loss: 9.2009 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.5000
# Epoch 15/20
# 41/41 [==============================] - 10s 255ms/step - loss: 0.4233 - Binary_accuracy: 0.8037 - Precision: 0.8663 - Recall: 0.7189 - TP: 583.0000 - TN: 719.0000 - FN: 228.0000 - FP: 90.0000 - AUC: 0.8698 - val_loss: 6.1824 - val_Binary_accuracy: 0.4988 - val_Precision: 0.5025 - val_Recall: 0.9854 - val_TP: 202.0000 - val_TN: 0.0000e+00 - val_FN: 3.0000 - val_FP: 200.0000 - val_AUC: 0.4597
# Epoch 16/20
# 41/41 [==============================] - 10s 248ms/step - loss: 0.4154 - Binary_accuracy: 0.8074 - Precision: 0.8868 - Recall: 0.7053 - TP: 572.0000 - TN: 736.0000 - FN: 239.0000 - FP: 73.0000 - AUC: 0.8703 - val_loss: 5.5261 - val_Binary_accuracy: 0.4889 - val_Precision: 0.4975 - val_Recall: 0.9610 - val_TP: 197.0000 - val_TN: 1.0000 - val_FN: 8.0000 - val_FP: 199.0000 - val_AUC: 0.4190
# Epoch 17/20
# 41/41 [==============================] - 9s 212ms/step - loss: 0.4152 - Binary_accuracy: 0.8043 - Precision: 0.8754 - Recall: 0.7102 - TP: 576.0000 - TN: 727.0000 - FN: 235.0000 - FP: 82.0000 - AUC: 0.8756 - val_loss: 6.4492 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.5050
# Epoch 18/20
# 41/41 [==============================] - 10s 254ms/step - loss: 0.4053 - Binary_accuracy: 0.8210 - Precision: 0.9039 - Recall: 0.7189 - TP: 583.0000 - TN: 747.0000 - FN: 228.0000 - FP: 62.0000 - AUC: 0.8792 - val_loss: 8.1407 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.5000
# Epoch 19/20
# 41/41 [==============================] - 10s 249ms/step - loss: 0.4187 - Binary_accuracy: 0.8049 - Precision: 0.8756 - Recall: 0.7115 - TP: 577.0000 - TN: 727.0000 - FN: 234.0000 - FP: 82.0000 - AUC: 0.8685 - val_loss: 8.4934 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.5050
# Epoch 20/20
# 41/41 [==============================] - 8s 206ms/step - loss: 0.3935 - Binary_accuracy: 0.8247 - Precision: 0.8824 - Recall: 0.7497 - TP: 608.0000 - TN: 728.0000 - FN: 203.0000 - FP: 81.0000 - AUC: 0.8899 - val_loss: 9.3530 - val_Binary_accuracy: 0.5062 - val_Precision: 0.5062 - val_Recall: 1.0000 - val_TP: 205.0000 - val_TN: 0.0000e+00 - val_FN: 0.0000e+00 - val_FP: 200.0000 - val_AUC: 0.5000
