# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import keras
import cv2
import pickle
import sklearn
import random

from sklearn.metrics import auc, f1_score, roc_curve, recall_score, precision_score, accuracy_score, confusion_matrix
from sklearn import metrics
from google.colab import files
from keras.preprocessing import image
# from keras.layers.serialization import activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.applications import *
from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model
from keras.models import load_model
from keras import backend as K
from PIL import Image
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import load_img

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_dir = '/content/drive/MyDrive/TIFF PET-CTWholeDataset'

training_set_dir = os.path.join(base_dir, 'trainingSet')
test_set_dir = os.path.join(base_dir, 'testSet')

train_lungCancer_dir = os.path.join(training_set_dir, 'lungCancer')
train_normal_dir = os.path.join(training_set_dir, 'normal')
test_lungCancer_dir = os.path.join(test_set_dir, 'lungCancer')
test_normal_dir = os.path.join(test_set_dir, 'normal')

# %%
print('total training lungCancer images:', len(os.listdir(train_lungCancer_dir)))
print('total training normal images:', len(os.listdir(train_normal_dir)))
print('total test lungCancer images:', len(os.listdir(test_lungCancer_dir)))
print('total test normal images:', len(os.listdir(test_normal_dir)))
# Out:
# total training lungCancer images: 719
# total training normal images: 726
# total test lungCancer images: 199
# total test normal images: 207

# %%
def check_data_leakage(directory1, directory2):
    filenames_dir1 = set(os.listdir(directory1))
    filenames_dir2 = set(os.listdir(directory2))

    common_filenames = filenames_dir1.intersection(filenames_dir2)

    if len(common_filenames) > 0:
        print("Data leakage detected!")
        print("Common image filenames between the directories:", common_filenames)
    else:
        print("No data leakage detected.")

# %%
check_data_leakage(train_lungCancer_dir, test_lungCancer_dir)
check_data_leakage(train_lungCancer_dir, test_normal_dir)
check_data_leakage(train_normal_dir, test_normal_dir)
check_data_leakage(train_normal_dir, test_lungCancer_dir)
# Out:
# No data leakage detected.
# No data leakage detected.
# No data leakage detected.
# No data leakage detected.

# %%
BATCH_SIZE= 80
image_height, image_width = 245, 457

train_datagen = ImageDataGenerator(rescale=1.0/255.0,
                                  rotation_range= 15,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  zoom_range=0.1,
                                  fill_mode='nearest')

train_generator = train_datagen.flow_from_directory(
        training_set_dir,
        target_size=(image_height, image_width),
        batch_size=BATCH_SIZE,
        class_mode='binary',
        shuffle = True)


test_datagen = ImageDataGenerator(rescale=1.0/255.0)

test_generator = test_datagen.flow_from_directory(
        test_set_dir,
        target_size=(image_height, image_width),
        batch_size=10,
        class_mode='binary')
# Out:
# Found 1445 images belonging to 2 classes.
# Found 406 images belonging to 2 classes.

# %%
pre_trained_model = InceptionV3(include_top=False,
                                        weights= 'imagenet',
                                        input_shape = (image_height, image_width, 3))

for layer in pre_trained_model.layers:
    layer.trainable = False

# %%
pre_trained_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 245, 457, 3)]        0         []
#
#  conv2d_94 (Conv2D)          (None, 122, 228, 32)         864       ['input_2[0][0]']
#
#  batch_normalization_94 (Ba  (None, 122, 228, 32)         96        ['conv2d_94[0][0]']
#  tchNormalization)
#
#  activation_95 (Activation)  (None, 122, 228, 32)         0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  conv2d_95 (Conv2D)          (None, 120, 226, 32)         9216      ['activation_95[0][0]']
#
#  batch_normalization_95 (Ba  (None, 120, 226, 32)         96        ['conv2d_95[0][0]']
#  tchNormalization)
#
#  activation_96 (Activation)  (None, 120, 226, 32)         0         ['batch_normalization_95[0][0]
#                                                                     ']
#
#  conv2d_96 (Conv2D)          (None, 120, 226, 64)         18432     ['activation_96[0][0]']
#
#  batch_normalization_96 (Ba  (None, 120, 226, 64)         192       ['conv2d_96[0][0]']
#  tchNormalization)
#
#  activation_97 (Activation)  (None, 120, 226, 64)         0         ['batch_normalization_96[0][0]
#                                                                     ']
#
#  max_pooling2d_4 (MaxPoolin  (None, 59, 112, 64)          0         ['activation_97[0][0]']
#  g2D)
#
#  conv2d_97 (Conv2D)          (None, 59, 112, 80)          5120      ['max_pooling2d_4[0][0]']
#
#  batch_normalization_97 (Ba  (None, 59, 112, 80)          240       ['conv2d_97[0][0]']
#  tchNormalization)
#
#  activation_98 (Activation)  (None, 59, 112, 80)          0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  conv2d_98 (Conv2D)          (None, 57, 110, 192)         138240    ['activation_98[0][0]']
#
#  batch_normalization_98 (Ba  (None, 57, 110, 192)         576       ['conv2d_98[0][0]']
#  tchNormalization)
#
#  activation_99 (Activation)  (None, 57, 110, 192)         0         ['batch_normalization_98[0][0]
#                                                                     ']
#
#  max_pooling2d_5 (MaxPoolin  (None, 28, 54, 192)          0         ['activation_99[0][0]']
#  g2D)
#
#  conv2d_102 (Conv2D)         (None, 28, 54, 64)           12288     ['max_pooling2d_5[0][0]']
#
#  batch_normalization_102 (B  (None, 28, 54, 64)           192       ['conv2d_102[0][0]']
#  atchNormalization)
#
#  activation_103 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_102[0][0
#  )                                                                  ]']
#
#  conv2d_100 (Conv2D)         (None, 28, 54, 48)           9216      ['max_pooling2d_5[0][0]']
#
#  conv2d_103 (Conv2D)         (None, 28, 54, 96)           55296     ['activation_103[0][0]']
#
#  batch_normalization_100 (B  (None, 28, 54, 48)           144       ['conv2d_100[0][0]']
#  atchNormalization)
#
#  batch_normalization_103 (B  (None, 28, 54, 96)           288       ['conv2d_103[0][0]']
#  atchNormalization)
#
#  activation_101 (Activation  (None, 28, 54, 48)           0         ['batch_normalization_100[0][0
#  )                                                                  ]']
#
#  activation_104 (Activation  (None, 28, 54, 96)           0         ['batch_normalization_103[0][0
#  )                                                                  ]']
#
#  average_pooling2d_9 (Avera  (None, 28, 54, 192)          0         ['max_pooling2d_5[0][0]']
#  gePooling2D)
#
#  conv2d_99 (Conv2D)          (None, 28, 54, 64)           12288     ['max_pooling2d_5[0][0]']
#
#  conv2d_101 (Conv2D)         (None, 28, 54, 64)           76800     ['activation_101[0][0]']
#
#  conv2d_104 (Conv2D)         (None, 28, 54, 96)           82944     ['activation_104[0][0]']
#
#  conv2d_105 (Conv2D)         (None, 28, 54, 32)           6144      ['average_pooling2d_9[0][0]']
#
#  batch_normalization_99 (Ba  (None, 28, 54, 64)           192       ['conv2d_99[0][0]']
#  tchNormalization)
#
#  batch_normalization_101 (B  (None, 28, 54, 64)           192       ['conv2d_101[0][0]']
#  atchNormalization)
#
#  batch_normalization_104 (B  (None, 28, 54, 96)           288       ['conv2d_104[0][0]']
#  atchNormalization)
#
#  batch_normalization_105 (B  (None, 28, 54, 32)           96        ['conv2d_105[0][0]']
#  atchNormalization)
#
#  activation_100 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_99[0][0]
#  )                                                                  ']
#
#  activation_102 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_101[0][0
#  )                                                                  ]']
#
#  activation_105 (Activation  (None, 28, 54, 96)           0         ['batch_normalization_104[0][0
#  )                                                                  ]']
#
#  activation_106 (Activation  (None, 28, 54, 32)           0         ['batch_normalization_105[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 28, 54, 256)          0         ['activation_100[0][0]',
#                                                                      'activation_102[0][0]',
#                                                                      'activation_105[0][0]',
#                                                                      'activation_106[0][0]']
#
#  conv2d_109 (Conv2D)         (None, 28, 54, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_109 (B  (None, 28, 54, 64)           192       ['conv2d_109[0][0]']
#  atchNormalization)
#
#  activation_110 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_109[0][0
#  )                                                                  ]']
#
#  conv2d_107 (Conv2D)         (None, 28, 54, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_110 (Conv2D)         (None, 28, 54, 96)           55296     ['activation_110[0][0]']
#
#  batch_normalization_107 (B  (None, 28, 54, 48)           144       ['conv2d_107[0][0]']
#  atchNormalization)
#
#  batch_normalization_110 (B  (None, 28, 54, 96)           288       ['conv2d_110[0][0]']
#  atchNormalization)
#
#  activation_108 (Activation  (None, 28, 54, 48)           0         ['batch_normalization_107[0][0
#  )                                                                  ]']
#
#  activation_111 (Activation  (None, 28, 54, 96)           0         ['batch_normalization_110[0][0
#  )                                                                  ]']
#
#  average_pooling2d_10 (Aver  (None, 28, 54, 256)          0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_106 (Conv2D)         (None, 28, 54, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_108 (Conv2D)         (None, 28, 54, 64)           76800     ['activation_108[0][0]']
#
#  conv2d_111 (Conv2D)         (None, 28, 54, 96)           82944     ['activation_111[0][0]']
#
#  conv2d_112 (Conv2D)         (None, 28, 54, 64)           16384     ['average_pooling2d_10[0][0]']
#
#  batch_normalization_106 (B  (None, 28, 54, 64)           192       ['conv2d_106[0][0]']
#  atchNormalization)
#
#  batch_normalization_108 (B  (None, 28, 54, 64)           192       ['conv2d_108[0][0]']
#  atchNormalization)
#
#  batch_normalization_111 (B  (None, 28, 54, 96)           288       ['conv2d_111[0][0]']
#  atchNormalization)
#
#  batch_normalization_112 (B  (None, 28, 54, 64)           192       ['conv2d_112[0][0]']
#  atchNormalization)
#
#  activation_107 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_106[0][0
#  )                                                                  ]']
#
#  activation_109 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_108[0][0
#  )                                                                  ]']
#
#  activation_112 (Activation  (None, 28, 54, 96)           0         ['batch_normalization_111[0][0
#  )                                                                  ]']
#
#  activation_113 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_112[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 28, 54, 288)          0         ['activation_107[0][0]',
#                                                                      'activation_109[0][0]',
#                                                                      'activation_112[0][0]',
#                                                                      'activation_113[0][0]']
#
#  conv2d_116 (Conv2D)         (None, 28, 54, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_116 (B  (None, 28, 54, 64)           192       ['conv2d_116[0][0]']
#  atchNormalization)
#
#  activation_117 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_116[0][0
#  )                                                                  ]']
#
#  conv2d_114 (Conv2D)         (None, 28, 54, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_117 (Conv2D)         (None, 28, 54, 96)           55296     ['activation_117[0][0]']
#
#  batch_normalization_114 (B  (None, 28, 54, 48)           144       ['conv2d_114[0][0]']
#  atchNormalization)
#
#  batch_normalization_117 (B  (None, 28, 54, 96)           288       ['conv2d_117[0][0]']
#  atchNormalization)
#
#  activation_115 (Activation  (None, 28, 54, 48)           0         ['batch_normalization_114[0][0
#  )                                                                  ]']
#
#  activation_118 (Activation  (None, 28, 54, 96)           0         ['batch_normalization_117[0][0
#  )                                                                  ]']
#
#  average_pooling2d_11 (Aver  (None, 28, 54, 288)          0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_113 (Conv2D)         (None, 28, 54, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_115 (Conv2D)         (None, 28, 54, 64)           76800     ['activation_115[0][0]']
#
#  conv2d_118 (Conv2D)         (None, 28, 54, 96)           82944     ['activation_118[0][0]']
#
#  conv2d_119 (Conv2D)         (None, 28, 54, 64)           18432     ['average_pooling2d_11[0][0]']
#
#  batch_normalization_113 (B  (None, 28, 54, 64)           192       ['conv2d_113[0][0]']
#  atchNormalization)
#
#  batch_normalization_115 (B  (None, 28, 54, 64)           192       ['conv2d_115[0][0]']
#  atchNormalization)
#
#  batch_normalization_118 (B  (None, 28, 54, 96)           288       ['conv2d_118[0][0]']
#  atchNormalization)
#
#  batch_normalization_119 (B  (None, 28, 54, 64)           192       ['conv2d_119[0][0]']
#  atchNormalization)
#
#  activation_114 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_113[0][0
#  )                                                                  ]']
#
#  activation_116 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_115[0][0
#  )                                                                  ]']
#
#  activation_119 (Activation  (None, 28, 54, 96)           0         ['batch_normalization_118[0][0
#  )                                                                  ]']
#
#  activation_120 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_119[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 28, 54, 288)          0         ['activation_114[0][0]',
#                                                                      'activation_116[0][0]',
#                                                                      'activation_119[0][0]',
#                                                                      'activation_120[0][0]']
#
#  conv2d_121 (Conv2D)         (None, 28, 54, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_121 (B  (None, 28, 54, 64)           192       ['conv2d_121[0][0]']
#  atchNormalization)
#
#  activation_122 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_121[0][0
#  )                                                                  ]']
#
#  conv2d_122 (Conv2D)         (None, 28, 54, 96)           55296     ['activation_122[0][0]']
#
#  batch_normalization_122 (B  (None, 28, 54, 96)           288       ['conv2d_122[0][0]']
#  atchNormalization)
#
#  activation_123 (Activation  (None, 28, 54, 96)           0         ['batch_normalization_122[0][0
#  )                                                                  ]']
#
#  conv2d_120 (Conv2D)         (None, 13, 26, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_123 (Conv2D)         (None, 13, 26, 96)           82944     ['activation_123[0][0]']
#
#  batch_normalization_120 (B  (None, 13, 26, 384)          1152      ['conv2d_120[0][0]']
#  atchNormalization)
#
#  batch_normalization_123 (B  (None, 13, 26, 96)           288       ['conv2d_123[0][0]']
#  atchNormalization)
#
#  activation_121 (Activation  (None, 13, 26, 384)          0         ['batch_normalization_120[0][0
#  )                                                                  ]']
#
#  activation_124 (Activation  (None, 13, 26, 96)           0         ['batch_normalization_123[0][0
#  )                                                                  ]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 13, 26, 288)          0         ['mixed2[0][0]']
#  g2D)
#
#  mixed3 (Concatenate)        (None, 13, 26, 768)          0         ['activation_121[0][0]',
#                                                                      'activation_124[0][0]',
#                                                                      'max_pooling2d_6[0][0]']
#
#  conv2d_128 (Conv2D)         (None, 13, 26, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_128 (B  (None, 13, 26, 128)          384       ['conv2d_128[0][0]']
#  atchNormalization)
#
#  activation_129 (Activation  (None, 13, 26, 128)          0         ['batch_normalization_128[0][0
#  )                                                                  ]']
#
#  conv2d_129 (Conv2D)         (None, 13, 26, 128)          114688    ['activation_129[0][0]']
#
#  batch_normalization_129 (B  (None, 13, 26, 128)          384       ['conv2d_129[0][0]']
#  atchNormalization)
#
#  activation_130 (Activation  (None, 13, 26, 128)          0         ['batch_normalization_129[0][0
#  )                                                                  ]']
#
#  conv2d_125 (Conv2D)         (None, 13, 26, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_130 (Conv2D)         (None, 13, 26, 128)          114688    ['activation_130[0][0]']
#
#  batch_normalization_125 (B  (None, 13, 26, 128)          384       ['conv2d_125[0][0]']
#  atchNormalization)
#
#  batch_normalization_130 (B  (None, 13, 26, 128)          384       ['conv2d_130[0][0]']
#  atchNormalization)
#
#  activation_126 (Activation  (None, 13, 26, 128)          0         ['batch_normalization_125[0][0
#  )                                                                  ]']
#
#  activation_131 (Activation  (None, 13, 26, 128)          0         ['batch_normalization_130[0][0
#  )                                                                  ]']
#
#  conv2d_126 (Conv2D)         (None, 13, 26, 128)          114688    ['activation_126[0][0]']
#
#  conv2d_131 (Conv2D)         (None, 13, 26, 128)          114688    ['activation_131[0][0]']
#
#  batch_normalization_126 (B  (None, 13, 26, 128)          384       ['conv2d_126[0][0]']
#  atchNormalization)
#
#  batch_normalization_131 (B  (None, 13, 26, 128)          384       ['conv2d_131[0][0]']
#  atchNormalization)
#
#  activation_127 (Activation  (None, 13, 26, 128)          0         ['batch_normalization_126[0][0
#  )                                                                  ]']
#
#  activation_132 (Activation  (None, 13, 26, 128)          0         ['batch_normalization_131[0][0
#  )                                                                  ]']
#
#  average_pooling2d_12 (Aver  (None, 13, 26, 768)          0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_124 (Conv2D)         (None, 13, 26, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_127 (Conv2D)         (None, 13, 26, 192)          172032    ['activation_127[0][0]']
#
#  conv2d_132 (Conv2D)         (None, 13, 26, 192)          172032    ['activation_132[0][0]']
#
#  conv2d_133 (Conv2D)         (None, 13, 26, 192)          147456    ['average_pooling2d_12[0][0]']
#
#  batch_normalization_124 (B  (None, 13, 26, 192)          576       ['conv2d_124[0][0]']
#  atchNormalization)
#
#  batch_normalization_127 (B  (None, 13, 26, 192)          576       ['conv2d_127[0][0]']
#  atchNormalization)
#
#  batch_normalization_132 (B  (None, 13, 26, 192)          576       ['conv2d_132[0][0]']
#  atchNormalization)
#
#  batch_normalization_133 (B  (None, 13, 26, 192)          576       ['conv2d_133[0][0]']
#  atchNormalization)
#
#  activation_125 (Activation  (None, 13, 26, 192)          0         ['batch_normalization_124[0][0
#  )                                                                  ]']
#
#  activation_128 (Activation  (None, 13, 26, 192)          0         ['batch_normalization_127[0][0
#  )                                                                  ]']
#
#  activation_133 (Activation  (None, 13, 26, 192)          0         ['batch_normalization_132[0][0
#  )                                                                  ]']
#
#  activation_134 (Activation  (None, 13, 26, 192)          0         ['batch_normalization_133[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 13, 26, 768)          0         ['activation_125[0][0]',
#                                                                      'activation_128[0][0]',
#                                                                      'activation_133[0][0]',
#                                                                      'activation_134[0][0]']
#
#  conv2d_138 (Conv2D)         (None, 13, 26, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_138 (B  (None, 13, 26, 160)          480       ['conv2d_138[0][0]']
#  atchNormalization)
#
#  activation_139 (Activation  (None, 13, 26, 160)          0         ['batch_normalization_138[0][0
#  )                                                                  ]']
#
#  conv2d_139 (Conv2D)         (None, 13, 26, 160)          179200    ['activation_139[0][0]']
#
#  batch_normalization_139 (B  (None, 13, 26, 160)          480       ['conv2d_139[0][0]']
#  atchNormalization)
#
#  activation_140 (Activation  (None, 13, 26, 160)          0         ['batch_normalization_139[0][0
#  )                                                                  ]']
#
#  conv2d_135 (Conv2D)         (None, 13, 26, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_140 (Conv2D)         (None, 13, 26, 160)          179200    ['activation_140[0][0]']
#
#  batch_normalization_135 (B  (None, 13, 26, 160)          480       ['conv2d_135[0][0]']
#  atchNormalization)
#
#  batch_normalization_140 (B  (None, 13, 26, 160)          480       ['conv2d_140[0][0]']
#  atchNormalization)
#
#  activation_136 (Activation  (None, 13, 26, 160)          0         ['batch_normalization_135[0][0
#  )                                                                  ]']
#
#  activation_141 (Activation  (None, 13, 26, 160)          0         ['batch_normalization_140[0][0
#  )                                                                  ]']
#
#  conv2d_136 (Conv2D)         (None, 13, 26, 160)          179200    ['activation_136[0][0]']
#
#  conv2d_141 (Conv2D)         (None, 13, 26, 160)          179200    ['activation_141[0][0]']
#
#  batch_normalization_136 (B  (None, 13, 26, 160)          480       ['conv2d_136[0][0]']
#  atchNormalization)
#
#  batch_normalization_141 (B  (None, 13, 26, 160)          480       ['conv2d_141[0][0]']
#  atchNormalization)
#
#  activation_137 (Activation  (None, 13, 26, 160)          0         ['batch_normalization_136[0][0
#  )                                                                  ]']
#
#  activation_142 (Activation  (None, 13, 26, 160)          0         ['batch_normalization_141[0][0
#  )                                                                  ]']
#
#  average_pooling2d_13 (Aver  (None, 13, 26, 768)          0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_134 (Conv2D)         (None, 13, 26, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_137 (Conv2D)         (None, 13, 26, 192)          215040    ['activation_137[0][0]']
#
#  conv2d_142 (Conv2D)         (None, 13, 26, 192)          215040    ['activation_142[0][0]']
#
#  conv2d_143 (Conv2D)         (None, 13, 26, 192)          147456    ['average_pooling2d_13[0][0]']
#
#  batch_normalization_134 (B  (None, 13, 26, 192)          576       ['conv2d_134[0][0]']
#  atchNormalization)
#
#  batch_normalization_137 (B  (None, 13, 26, 192)          576       ['conv2d_137[0][0]']
#  atchNormalization)
#
#  batch_normalization_142 (B  (None, 13, 26, 192)          576       ['conv2d_142[0][0]']
#  atchNormalization)
#
#  batch_normalization_143 (B  (None, 13, 26, 192)          576       ['conv2d_143[0][0]']
#  atchNormalization)
#
#  activation_135 (Activation  (None, 13, 26, 192)          0         ['batch_normalization_134[0][0
#  )                                                                  ]']
#
#  activation_138 (Activation  (None, 13, 26, 192)          0         ['batch_normalization_137[0][0
#  )                                                                  ]']
#
#  activation_143 (Activation  (None, 13, 26, 192)          0         ['batch_normalization_142[0][0
#  )                                                                  ]']
#
#  activation_144 (Activation  (None, 13, 26, 192)          0         ['batch_normalization_143[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 13, 26, 768)          0         ['activation_135[0][0]',
#                                                                      'activation_138[0][0]',
#                                                                      'activation_143[0][0]',
#                                                                      'activation_144[0][0]']
#
#  conv2d_148 (Conv2D)         (None, 13, 26, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_148 (B  (None, 13, 26, 160)          480       ['conv2d_148[0][0]']
#  atchNormalization)
#
#  activation_149 (Activation  (None, 13, 26, 160)          0         ['batch_normalization_148[0][0
#  )                                                                  ]']
#
#  conv2d_149 (Conv2D)         (None, 13, 26, 160)          179200    ['activation_149[0][0]']
#
#  batch_normalization_149 (B  (None, 13, 26, 160)          480       ['conv2d_149[0][0]']
#  atchNormalization)
#
#  activation_150 (Activation  (None, 13, 26, 160)          0         ['batch_normalization_149[0][0
#  )                                                                  ]']
#
#  conv2d_145 (Conv2D)         (None, 13, 26, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_150 (Conv2D)         (None, 13, 26, 160)          179200    ['activation_150[0][0]']
#
#  batch_normalization_145 (B  (None, 13, 26, 160)          480       ['conv2d_145[0][0]']
#  atchNormalization)
#
#  batch_normalization_150 (B  (None, 13, 26, 160)          480       ['conv2d_150[0][0]']
#  atchNormalization)
#
# ...
#
#  batch_normalization_175 (B  (None, 6, 12, 384)           1152      ['conv2d_175[0][0]']
#  atchNormalization)
#
#  activation_172 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_171[0][0
#  )                                                                  ]']
#
#  activation_176 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_175[0][0
#  )                                                                  ]']
#
#  conv2d_172 (Conv2D)         (None, 6, 12, 384)           442368    ['activation_172[0][0]']
#
#  conv2d_173 (Conv2D)         (None, 6, 12, 384)           442368    ['activation_172[0][0]']
#
#  conv2d_176 (Conv2D)         (None, 6, 12, 384)           442368    ['activation_176[0][0]']
#
#  conv2d_177 (Conv2D)         (None, 6, 12, 384)           442368    ['activation_176[0][0]']
#
#  average_pooling2d_16 (Aver  (None, 6, 12, 1280)          0         ['mixed8[0][0]']
#  agePooling2D)
#
#  conv2d_170 (Conv2D)         (None, 6, 12, 320)           409600    ['mixed8[0][0]']
#
#  batch_normalization_172 (B  (None, 6, 12, 384)           1152      ['conv2d_172[0][0]']
#  atchNormalization)
#
#  batch_normalization_173 (B  (None, 6, 12, 384)           1152      ['conv2d_173[0][0]']
#  atchNormalization)
#
#  batch_normalization_176 (B  (None, 6, 12, 384)           1152      ['conv2d_176[0][0]']
#  atchNormalization)
#
#  batch_normalization_177 (B  (None, 6, 12, 384)           1152      ['conv2d_177[0][0]']
#  atchNormalization)
#
#  conv2d_178 (Conv2D)         (None, 6, 12, 192)           245760    ['average_pooling2d_16[0][0]']
#
#  batch_normalization_170 (B  (None, 6, 12, 320)           960       ['conv2d_170[0][0]']
#  atchNormalization)
#
#  activation_173 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_172[0][0
#  )                                                                  ]']
#
#  activation_174 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_173[0][0
#  )                                                                  ]']
#
#  activation_177 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_176[0][0
#  )                                                                  ]']
#
#  activation_178 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_177[0][0
#  )                                                                  ]']
#
#  batch_normalization_178 (B  (None, 6, 12, 192)           576       ['conv2d_178[0][0]']
#  atchNormalization)
#
#  activation_171 (Activation  (None, 6, 12, 320)           0         ['batch_normalization_170[0][0
#  )                                                                  ]']
#
#  mixed9_0 (Concatenate)      (None, 6, 12, 768)           0         ['activation_173[0][0]',
#                                                                      'activation_174[0][0]']
#
#  concatenate_2 (Concatenate  (None, 6, 12, 768)           0         ['activation_177[0][0]',
#  )                                                                   'activation_178[0][0]']
#
#  activation_179 (Activation  (None, 6, 12, 192)           0         ['batch_normalization_178[0][0
#  )                                                                  ]']
#
#  mixed9 (Concatenate)        (None, 6, 12, 2048)          0         ['activation_171[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_2[0][0]',
#                                                                      'activation_179[0][0]']
#
#  conv2d_183 (Conv2D)         (None, 6, 12, 448)           917504    ['mixed9[0][0]']
#
#  batch_normalization_183 (B  (None, 6, 12, 448)           1344      ['conv2d_183[0][0]']
#  atchNormalization)
#
#  activation_184 (Activation  (None, 6, 12, 448)           0         ['batch_normalization_183[0][0
#  )                                                                  ]']
#
#  conv2d_180 (Conv2D)         (None, 6, 12, 384)           786432    ['mixed9[0][0]']
#
#  conv2d_184 (Conv2D)         (None, 6, 12, 384)           1548288   ['activation_184[0][0]']
#
#  batch_normalization_180 (B  (None, 6, 12, 384)           1152      ['conv2d_180[0][0]']
#  atchNormalization)
#
#  batch_normalization_184 (B  (None, 6, 12, 384)           1152      ['conv2d_184[0][0]']
#  atchNormalization)
#
#  activation_181 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_180[0][0
#  )                                                                  ]']
#
#  activation_185 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_184[0][0
#  )                                                                  ]']
#
#  conv2d_181 (Conv2D)         (None, 6, 12, 384)           442368    ['activation_181[0][0]']
#
#  conv2d_182 (Conv2D)         (None, 6, 12, 384)           442368    ['activation_181[0][0]']
#
#  conv2d_185 (Conv2D)         (None, 6, 12, 384)           442368    ['activation_185[0][0]']
#
#  conv2d_186 (Conv2D)         (None, 6, 12, 384)           442368    ['activation_185[0][0]']
#
#  average_pooling2d_17 (Aver  (None, 6, 12, 2048)          0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_179 (Conv2D)         (None, 6, 12, 320)           655360    ['mixed9[0][0]']
#
#  batch_normalization_181 (B  (None, 6, 12, 384)           1152      ['conv2d_181[0][0]']
#  atchNormalization)
#
#  batch_normalization_182 (B  (None, 6, 12, 384)           1152      ['conv2d_182[0][0]']
#  atchNormalization)
#
#  batch_normalization_185 (B  (None, 6, 12, 384)           1152      ['conv2d_185[0][0]']
#  atchNormalization)
#
#  batch_normalization_186 (B  (None, 6, 12, 384)           1152      ['conv2d_186[0][0]']
#  atchNormalization)
#
#  conv2d_187 (Conv2D)         (None, 6, 12, 192)           393216    ['average_pooling2d_17[0][0]']
#
#  batch_normalization_179 (B  (None, 6, 12, 320)           960       ['conv2d_179[0][0]']
#  atchNormalization)
#
#  activation_182 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_181[0][0
#  )                                                                  ]']
#
#  activation_183 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_182[0][0
#  )                                                                  ]']
#
#  activation_186 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_185[0][0
#  )                                                                  ]']
#
#  activation_187 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_186[0][0
#  )                                                                  ]']
#
#  batch_normalization_187 (B  (None, 6, 12, 192)           576       ['conv2d_187[0][0]']
#  atchNormalization)
#
#  activation_180 (Activation  (None, 6, 12, 320)           0         ['batch_normalization_179[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (None, 6, 12, 768)           0         ['activation_182[0][0]',
#                                                                      'activation_183[0][0]']
#
#  concatenate_3 (Concatenate  (None, 6, 12, 768)           0         ['activation_186[0][0]',
#  )                                                                   'activation_187[0][0]']
#
#  activation_188 (Activation  (None, 6, 12, 192)           0         ['batch_normalization_187[0][0
#  )                                                                  ]']
#
#  mixed10 (Concatenate)       (None, 6, 12, 2048)          0         ['activation_180[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_3[0][0]',
#                                                                      'activation_188[0][0]']
#
# ==================================================================================================
# Total params: 21802784 (83.17 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 21802784 (83.17 MB)
# __________________________________________________________________________________________________

# %%
last_layer = pre_trained_model.get_layer('mixed10')
print('last layer output shape: ', last_layer.output_shape)
last_output = last_layer.output

x = layers.Flatten()(last_output)
x = layers.Dense(1024, activation='relu')(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dense(32, activation='relu')(x)
x = layers.Dense(1)(x)
x = layers.Activation(tf.nn.sigmoid)(x)

model = Model(pre_trained_model.input, x)
# Out:
# last layer output shape:  (None, 6, 12, 2048)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 245, 457, 3)]        0         []
#
#  conv2d_94 (Conv2D)          (None, 122, 228, 32)         864       ['input_2[0][0]']
#
#  batch_normalization_94 (Ba  (None, 122, 228, 32)         96        ['conv2d_94[0][0]']
#  tchNormalization)
#
#  activation_95 (Activation)  (None, 122, 228, 32)         0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  conv2d_95 (Conv2D)          (None, 120, 226, 32)         9216      ['activation_95[0][0]']
#
#  batch_normalization_95 (Ba  (None, 120, 226, 32)         96        ['conv2d_95[0][0]']
#  tchNormalization)
#
#  activation_96 (Activation)  (None, 120, 226, 32)         0         ['batch_normalization_95[0][0]
#                                                                     ']
#
#  conv2d_96 (Conv2D)          (None, 120, 226, 64)         18432     ['activation_96[0][0]']
#
#  batch_normalization_96 (Ba  (None, 120, 226, 64)         192       ['conv2d_96[0][0]']
#  tchNormalization)
#
#  activation_97 (Activation)  (None, 120, 226, 64)         0         ['batch_normalization_96[0][0]
#                                                                     ']
#
#  max_pooling2d_4 (MaxPoolin  (None, 59, 112, 64)          0         ['activation_97[0][0]']
#  g2D)
#
#  conv2d_97 (Conv2D)          (None, 59, 112, 80)          5120      ['max_pooling2d_4[0][0]']
#
#  batch_normalization_97 (Ba  (None, 59, 112, 80)          240       ['conv2d_97[0][0]']
#  tchNormalization)
#
#  activation_98 (Activation)  (None, 59, 112, 80)          0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  conv2d_98 (Conv2D)          (None, 57, 110, 192)         138240    ['activation_98[0][0]']
#
#  batch_normalization_98 (Ba  (None, 57, 110, 192)         576       ['conv2d_98[0][0]']
#  tchNormalization)
#
#  activation_99 (Activation)  (None, 57, 110, 192)         0         ['batch_normalization_98[0][0]
#                                                                     ']
#
#  max_pooling2d_5 (MaxPoolin  (None, 28, 54, 192)          0         ['activation_99[0][0]']
#  g2D)
#
#  conv2d_102 (Conv2D)         (None, 28, 54, 64)           12288     ['max_pooling2d_5[0][0]']
#
#  batch_normalization_102 (B  (None, 28, 54, 64)           192       ['conv2d_102[0][0]']
#  atchNormalization)
#
#  activation_103 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_102[0][0
#  )                                                                  ]']
#
#  conv2d_100 (Conv2D)         (None, 28, 54, 48)           9216      ['max_pooling2d_5[0][0]']
#
#  conv2d_103 (Conv2D)         (None, 28, 54, 96)           55296     ['activation_103[0][0]']
#
#  batch_normalization_100 (B  (None, 28, 54, 48)           144       ['conv2d_100[0][0]']
#  atchNormalization)
#
#  batch_normalization_103 (B  (None, 28, 54, 96)           288       ['conv2d_103[0][0]']
#  atchNormalization)
#
#  activation_101 (Activation  (None, 28, 54, 48)           0         ['batch_normalization_100[0][0
#  )                                                                  ]']
#
#  activation_104 (Activation  (None, 28, 54, 96)           0         ['batch_normalization_103[0][0
#  )                                                                  ]']
#
#  average_pooling2d_9 (Avera  (None, 28, 54, 192)          0         ['max_pooling2d_5[0][0]']
#  gePooling2D)
#
#  conv2d_99 (Conv2D)          (None, 28, 54, 64)           12288     ['max_pooling2d_5[0][0]']
#
#  conv2d_101 (Conv2D)         (None, 28, 54, 64)           76800     ['activation_101[0][0]']
#
#  conv2d_104 (Conv2D)         (None, 28, 54, 96)           82944     ['activation_104[0][0]']
#
#  conv2d_105 (Conv2D)         (None, 28, 54, 32)           6144      ['average_pooling2d_9[0][0]']
#
#  batch_normalization_99 (Ba  (None, 28, 54, 64)           192       ['conv2d_99[0][0]']
#  tchNormalization)
#
#  batch_normalization_101 (B  (None, 28, 54, 64)           192       ['conv2d_101[0][0]']
#  atchNormalization)
#
#  batch_normalization_104 (B  (None, 28, 54, 96)           288       ['conv2d_104[0][0]']
#  atchNormalization)
#
#  batch_normalization_105 (B  (None, 28, 54, 32)           96        ['conv2d_105[0][0]']
#  atchNormalization)
#
#  activation_100 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_99[0][0]
#  )                                                                  ']
#
#  activation_102 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_101[0][0
#  )                                                                  ]']
#
#  activation_105 (Activation  (None, 28, 54, 96)           0         ['batch_normalization_104[0][0
#  )                                                                  ]']
#
#  activation_106 (Activation  (None, 28, 54, 32)           0         ['batch_normalization_105[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 28, 54, 256)          0         ['activation_100[0][0]',
#                                                                      'activation_102[0][0]',
#                                                                      'activation_105[0][0]',
#                                                                      'activation_106[0][0]']
#
#  conv2d_109 (Conv2D)         (None, 28, 54, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_109 (B  (None, 28, 54, 64)           192       ['conv2d_109[0][0]']
#  atchNormalization)
#
#  activation_110 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_109[0][0
#  )                                                                  ]']
#
#  conv2d_107 (Conv2D)         (None, 28, 54, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_110 (Conv2D)         (None, 28, 54, 96)           55296     ['activation_110[0][0]']
#
#  batch_normalization_107 (B  (None, 28, 54, 48)           144       ['conv2d_107[0][0]']
#  atchNormalization)
#
#  batch_normalization_110 (B  (None, 28, 54, 96)           288       ['conv2d_110[0][0]']
#  atchNormalization)
#
#  activation_108 (Activation  (None, 28, 54, 48)           0         ['batch_normalization_107[0][0
#  )                                                                  ]']
#
#  activation_111 (Activation  (None, 28, 54, 96)           0         ['batch_normalization_110[0][0
#  )                                                                  ]']
#
#  average_pooling2d_10 (Aver  (None, 28, 54, 256)          0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_106 (Conv2D)         (None, 28, 54, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_108 (Conv2D)         (None, 28, 54, 64)           76800     ['activation_108[0][0]']
#
#  conv2d_111 (Conv2D)         (None, 28, 54, 96)           82944     ['activation_111[0][0]']
#
#  conv2d_112 (Conv2D)         (None, 28, 54, 64)           16384     ['average_pooling2d_10[0][0]']
#
#  batch_normalization_106 (B  (None, 28, 54, 64)           192       ['conv2d_106[0][0]']
#  atchNormalization)
#
#  batch_normalization_108 (B  (None, 28, 54, 64)           192       ['conv2d_108[0][0]']
#  atchNormalization)
#
#  batch_normalization_111 (B  (None, 28, 54, 96)           288       ['conv2d_111[0][0]']
#  atchNormalization)
#
#  batch_normalization_112 (B  (None, 28, 54, 64)           192       ['conv2d_112[0][0]']
#  atchNormalization)
#
#  activation_107 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_106[0][0
#  )                                                                  ]']
#
#  activation_109 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_108[0][0
#  )                                                                  ]']
#
#  activation_112 (Activation  (None, 28, 54, 96)           0         ['batch_normalization_111[0][0
#  )                                                                  ]']
#
#  activation_113 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_112[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 28, 54, 288)          0         ['activation_107[0][0]',
#                                                                      'activation_109[0][0]',
#                                                                      'activation_112[0][0]',
#                                                                      'activation_113[0][0]']
#
#  conv2d_116 (Conv2D)         (None, 28, 54, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_116 (B  (None, 28, 54, 64)           192       ['conv2d_116[0][0]']
#  atchNormalization)
#
#  activation_117 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_116[0][0
#  )                                                                  ]']
#
#  conv2d_114 (Conv2D)         (None, 28, 54, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_117 (Conv2D)         (None, 28, 54, 96)           55296     ['activation_117[0][0]']
#
#  batch_normalization_114 (B  (None, 28, 54, 48)           144       ['conv2d_114[0][0]']
#  atchNormalization)
#
#  batch_normalization_117 (B  (None, 28, 54, 96)           288       ['conv2d_117[0][0]']
#  atchNormalization)
#
#  activation_115 (Activation  (None, 28, 54, 48)           0         ['batch_normalization_114[0][0
#  )                                                                  ]']
#
#  activation_118 (Activation  (None, 28, 54, 96)           0         ['batch_normalization_117[0][0
#  )                                                                  ]']
#
#  average_pooling2d_11 (Aver  (None, 28, 54, 288)          0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_113 (Conv2D)         (None, 28, 54, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_115 (Conv2D)         (None, 28, 54, 64)           76800     ['activation_115[0][0]']
#
#  conv2d_118 (Conv2D)         (None, 28, 54, 96)           82944     ['activation_118[0][0]']
#
#  conv2d_119 (Conv2D)         (None, 28, 54, 64)           18432     ['average_pooling2d_11[0][0]']
#
#  batch_normalization_113 (B  (None, 28, 54, 64)           192       ['conv2d_113[0][0]']
#  atchNormalization)
#
#  batch_normalization_115 (B  (None, 28, 54, 64)           192       ['conv2d_115[0][0]']
#  atchNormalization)
#
#  batch_normalization_118 (B  (None, 28, 54, 96)           288       ['conv2d_118[0][0]']
#  atchNormalization)
#
#  batch_normalization_119 (B  (None, 28, 54, 64)           192       ['conv2d_119[0][0]']
#  atchNormalization)
#
#  activation_114 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_113[0][0
#  )                                                                  ]']
#
#  activation_116 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_115[0][0
#  )                                                                  ]']
#
#  activation_119 (Activation  (None, 28, 54, 96)           0         ['batch_normalization_118[0][0
#  )                                                                  ]']
#
#  activation_120 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_119[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 28, 54, 288)          0         ['activation_114[0][0]',
#                                                                      'activation_116[0][0]',
#                                                                      'activation_119[0][0]',
#                                                                      'activation_120[0][0]']
#
#  conv2d_121 (Conv2D)         (None, 28, 54, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_121 (B  (None, 28, 54, 64)           192       ['conv2d_121[0][0]']
#  atchNormalization)
#
#  activation_122 (Activation  (None, 28, 54, 64)           0         ['batch_normalization_121[0][0
#  )                                                                  ]']
#
#  conv2d_122 (Conv2D)         (None, 28, 54, 96)           55296     ['activation_122[0][0]']
#
#  batch_normalization_122 (B  (None, 28, 54, 96)           288       ['conv2d_122[0][0]']
#  atchNormalization)
#
#  activation_123 (Activation  (None, 28, 54, 96)           0         ['batch_normalization_122[0][0
#  )                                                                  ]']
#
#  conv2d_120 (Conv2D)         (None, 13, 26, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_123 (Conv2D)         (None, 13, 26, 96)           82944     ['activation_123[0][0]']
#
#  batch_normalization_120 (B  (None, 13, 26, 384)          1152      ['conv2d_120[0][0]']
#  atchNormalization)
#
#  batch_normalization_123 (B  (None, 13, 26, 96)           288       ['conv2d_123[0][0]']
#  atchNormalization)
#
#  activation_121 (Activation  (None, 13, 26, 384)          0         ['batch_normalization_120[0][0
#  )                                                                  ]']
#
#  activation_124 (Activation  (None, 13, 26, 96)           0         ['batch_normalization_123[0][0
#  )                                                                  ]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 13, 26, 288)          0         ['mixed2[0][0]']
#  g2D)
#
#  mixed3 (Concatenate)        (None, 13, 26, 768)          0         ['activation_121[0][0]',
#                                                                      'activation_124[0][0]',
#                                                                      'max_pooling2d_6[0][0]']
#
#  conv2d_128 (Conv2D)         (None, 13, 26, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_128 (B  (None, 13, 26, 128)          384       ['conv2d_128[0][0]']
#  atchNormalization)
#
#  activation_129 (Activation  (None, 13, 26, 128)          0         ['batch_normalization_128[0][0
#  )                                                                  ]']
#
#  conv2d_129 (Conv2D)         (None, 13, 26, 128)          114688    ['activation_129[0][0]']
#
#  batch_normalization_129 (B  (None, 13, 26, 128)          384       ['conv2d_129[0][0]']
#  atchNormalization)
#
#  activation_130 (Activation  (None, 13, 26, 128)          0         ['batch_normalization_129[0][0
#  )                                                                  ]']
#
#  conv2d_125 (Conv2D)         (None, 13, 26, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_130 (Conv2D)         (None, 13, 26, 128)          114688    ['activation_130[0][0]']
#
#  batch_normalization_125 (B  (None, 13, 26, 128)          384       ['conv2d_125[0][0]']
#  atchNormalization)
#
#  batch_normalization_130 (B  (None, 13, 26, 128)          384       ['conv2d_130[0][0]']
#  atchNormalization)
#
#  activation_126 (Activation  (None, 13, 26, 128)          0         ['batch_normalization_125[0][0
#  )                                                                  ]']
#
#  activation_131 (Activation  (None, 13, 26, 128)          0         ['batch_normalization_130[0][0
#  )                                                                  ]']
#
#  conv2d_126 (Conv2D)         (None, 13, 26, 128)          114688    ['activation_126[0][0]']
#
#  conv2d_131 (Conv2D)         (None, 13, 26, 128)          114688    ['activation_131[0][0]']
#
#  batch_normalization_126 (B  (None, 13, 26, 128)          384       ['conv2d_126[0][0]']
#  atchNormalization)
#
#  batch_normalization_131 (B  (None, 13, 26, 128)          384       ['conv2d_131[0][0]']
#  atchNormalization)
#
#  activation_127 (Activation  (None, 13, 26, 128)          0         ['batch_normalization_126[0][0
#  )                                                                  ]']
#
#  activation_132 (Activation  (None, 13, 26, 128)          0         ['batch_normalization_131[0][0
#  )                                                                  ]']
#
#  average_pooling2d_12 (Aver  (None, 13, 26, 768)          0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_124 (Conv2D)         (None, 13, 26, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_127 (Conv2D)         (None, 13, 26, 192)          172032    ['activation_127[0][0]']
#
#  conv2d_132 (Conv2D)         (None, 13, 26, 192)          172032    ['activation_132[0][0]']
#
#  conv2d_133 (Conv2D)         (None, 13, 26, 192)          147456    ['average_pooling2d_12[0][0]']
#
#  batch_normalization_124 (B  (None, 13, 26, 192)          576       ['conv2d_124[0][0]']
#  atchNormalization)
#
#  batch_normalization_127 (B  (None, 13, 26, 192)          576       ['conv2d_127[0][0]']
#  atchNormalization)
#
#  batch_normalization_132 (B  (None, 13, 26, 192)          576       ['conv2d_132[0][0]']
#  atchNormalization)
#
#  batch_normalization_133 (B  (None, 13, 26, 192)          576       ['conv2d_133[0][0]']
#  atchNormalization)
#
#  activation_125 (Activation  (None, 13, 26, 192)          0         ['batch_normalization_124[0][0
#  )                                                                  ]']
#
#  activation_128 (Activation  (None, 13, 26, 192)          0         ['batch_normalization_127[0][0
#  )                                                                  ]']
#
#  activation_133 (Activation  (None, 13, 26, 192)          0         ['batch_normalization_132[0][0
#  )                                                                  ]']
#
#  activation_134 (Activation  (None, 13, 26, 192)          0         ['batch_normalization_133[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 13, 26, 768)          0         ['activation_125[0][0]',
#                                                                      'activation_128[0][0]',
#                                                                      'activation_133[0][0]',
#                                                                      'activation_134[0][0]']
#
#  conv2d_138 (Conv2D)         (None, 13, 26, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_138 (B  (None, 13, 26, 160)          480       ['conv2d_138[0][0]']
#  atchNormalization)
#
#  activation_139 (Activation  (None, 13, 26, 160)          0         ['batch_normalization_138[0][0
#  )                                                                  ]']
#
#  conv2d_139 (Conv2D)         (None, 13, 26, 160)          179200    ['activation_139[0][0]']
#
#  batch_normalization_139 (B  (None, 13, 26, 160)          480       ['conv2d_139[0][0]']
#  atchNormalization)
#
#  activation_140 (Activation  (None, 13, 26, 160)          0         ['batch_normalization_139[0][0
#  )                                                                  ]']
#
#  conv2d_135 (Conv2D)         (None, 13, 26, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_140 (Conv2D)         (None, 13, 26, 160)          179200    ['activation_140[0][0]']
#
#  batch_normalization_135 (B  (None, 13, 26, 160)          480       ['conv2d_135[0][0]']
#  atchNormalization)
#
#  batch_normalization_140 (B  (None, 13, 26, 160)          480       ['conv2d_140[0][0]']
#  atchNormalization)
#
#  activation_136 (Activation  (None, 13, 26, 160)          0         ['batch_normalization_135[0][0
#  )                                                                  ]']
#
#  activation_141 (Activation  (None, 13, 26, 160)          0         ['batch_normalization_140[0][0
#  )                                                                  ]']
#
#  conv2d_136 (Conv2D)         (None, 13, 26, 160)          179200    ['activation_136[0][0]']
#
#  conv2d_141 (Conv2D)         (None, 13, 26, 160)          179200    ['activation_141[0][0]']
#
#  batch_normalization_136 (B  (None, 13, 26, 160)          480       ['conv2d_136[0][0]']
#  atchNormalization)
#
#  batch_normalization_141 (B  (None, 13, 26, 160)          480       ['conv2d_141[0][0]']
#  atchNormalization)
#
#  activation_137 (Activation  (None, 13, 26, 160)          0         ['batch_normalization_136[0][0
#  )                                                                  ]']
#
#  activation_142 (Activation  (None, 13, 26, 160)          0         ['batch_normalization_141[0][0
#  )                                                                  ]']
#
#  average_pooling2d_13 (Aver  (None, 13, 26, 768)          0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_134 (Conv2D)         (None, 13, 26, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_137 (Conv2D)         (None, 13, 26, 192)          215040    ['activation_137[0][0]']
#
#  conv2d_142 (Conv2D)         (None, 13, 26, 192)          215040    ['activation_142[0][0]']
#
#  conv2d_143 (Conv2D)         (None, 13, 26, 192)          147456    ['average_pooling2d_13[0][0]']
#
#  batch_normalization_134 (B  (None, 13, 26, 192)          576       ['conv2d_134[0][0]']
#  atchNormalization)
#
#  batch_normalization_137 (B  (None, 13, 26, 192)          576       ['conv2d_137[0][0]']
#  atchNormalization)
#
#  batch_normalization_142 (B  (None, 13, 26, 192)          576       ['conv2d_142[0][0]']
#  atchNormalization)
#
#  batch_normalization_143 (B  (None, 13, 26, 192)          576       ['conv2d_143[0][0]']
#  atchNormalization)
#
#  activation_135 (Activation  (None, 13, 26, 192)          0         ['batch_normalization_134[0][0
#  )                                                                  ]']
#
#  activation_138 (Activation  (None, 13, 26, 192)          0         ['batch_normalization_137[0][0
#  )                                                                  ]']
#
#  activation_143 (Activation  (None, 13, 26, 192)          0         ['batch_normalization_142[0][0
#  )                                                                  ]']
#
#  activation_144 (Activation  (None, 13, 26, 192)          0         ['batch_normalization_143[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 13, 26, 768)          0         ['activation_135[0][0]',
#                                                                      'activation_138[0][0]',
#                                                                      'activation_143[0][0]',
#                                                                      'activation_144[0][0]']
#
#  conv2d_148 (Conv2D)         (None, 13, 26, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_148 (B  (None, 13, 26, 160)          480       ['conv2d_148[0][0]']
#  atchNormalization)
#
#  activation_149 (Activation  (None, 13, 26, 160)          0         ['batch_normalization_148[0][0
#  )                                                                  ]']
#
#  conv2d_149 (Conv2D)         (None, 13, 26, 160)          179200    ['activation_149[0][0]']
#
#  batch_normalization_149 (B  (None, 13, 26, 160)          480       ['conv2d_149[0][0]']
#  atchNormalization)
#
#  activation_150 (Activation  (None, 13, 26, 160)          0         ['batch_normalization_149[0][0
#  )                                                                  ]']
#
#  conv2d_145 (Conv2D)         (None, 13, 26, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_150 (Conv2D)         (None, 13, 26, 160)          179200    ['activation_150[0][0]']
#
#  batch_normalization_145 (B  (None, 13, 26, 160)          480       ['conv2d_145[0][0]']
#  atchNormalization)
#
#  batch_normalization_150 (B  (None, 13, 26, 160)          480       ['conv2d_150[0][0]']
#  atchNormalization)
#
# ...
#  average_pooling2d_16 (Aver  (None, 6, 12, 1280)          0         ['mixed8[0][0]']
#  agePooling2D)
#
#  conv2d_170 (Conv2D)         (None, 6, 12, 320)           409600    ['mixed8[0][0]']
#
#  batch_normalization_172 (B  (None, 6, 12, 384)           1152      ['conv2d_172[0][0]']
#  atchNormalization)
#
#  batch_normalization_173 (B  (None, 6, 12, 384)           1152      ['conv2d_173[0][0]']
#  atchNormalization)
#
#  batch_normalization_176 (B  (None, 6, 12, 384)           1152      ['conv2d_176[0][0]']
#  atchNormalization)
#
#  batch_normalization_177 (B  (None, 6, 12, 384)           1152      ['conv2d_177[0][0]']
#  atchNormalization)
#
#  conv2d_178 (Conv2D)         (None, 6, 12, 192)           245760    ['average_pooling2d_16[0][0]']
#
#  batch_normalization_170 (B  (None, 6, 12, 320)           960       ['conv2d_170[0][0]']
#  atchNormalization)
#
#  activation_173 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_172[0][0
#  )                                                                  ]']
#
#  activation_174 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_173[0][0
#  )                                                                  ]']
#
#  activation_177 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_176[0][0
#  )                                                                  ]']
#
#  activation_178 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_177[0][0
#  )                                                                  ]']
#
#  batch_normalization_178 (B  (None, 6, 12, 192)           576       ['conv2d_178[0][0]']
#  atchNormalization)
#
#  activation_171 (Activation  (None, 6, 12, 320)           0         ['batch_normalization_170[0][0
#  )                                                                  ]']
#
#  mixed9_0 (Concatenate)      (None, 6, 12, 768)           0         ['activation_173[0][0]',
#                                                                      'activation_174[0][0]']
#
#  concatenate_2 (Concatenate  (None, 6, 12, 768)           0         ['activation_177[0][0]',
#  )                                                                   'activation_178[0][0]']
#
#  activation_179 (Activation  (None, 6, 12, 192)           0         ['batch_normalization_178[0][0
#  )                                                                  ]']
#
#  mixed9 (Concatenate)        (None, 6, 12, 2048)          0         ['activation_171[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_2[0][0]',
#                                                                      'activation_179[0][0]']
#
#  conv2d_183 (Conv2D)         (None, 6, 12, 448)           917504    ['mixed9[0][0]']
#
#  batch_normalization_183 (B  (None, 6, 12, 448)           1344      ['conv2d_183[0][0]']
#  atchNormalization)
#
#  activation_184 (Activation  (None, 6, 12, 448)           0         ['batch_normalization_183[0][0
#  )                                                                  ]']
#
#  conv2d_180 (Conv2D)         (None, 6, 12, 384)           786432    ['mixed9[0][0]']
#
#  conv2d_184 (Conv2D)         (None, 6, 12, 384)           1548288   ['activation_184[0][0]']
#
#  batch_normalization_180 (B  (None, 6, 12, 384)           1152      ['conv2d_180[0][0]']
#  atchNormalization)
#
#  batch_normalization_184 (B  (None, 6, 12, 384)           1152      ['conv2d_184[0][0]']
#  atchNormalization)
#
#  activation_181 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_180[0][0
#  )                                                                  ]']
#
#  activation_185 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_184[0][0
#  )                                                                  ]']
#
#  conv2d_181 (Conv2D)         (None, 6, 12, 384)           442368    ['activation_181[0][0]']
#
#  conv2d_182 (Conv2D)         (None, 6, 12, 384)           442368    ['activation_181[0][0]']
#
#  conv2d_185 (Conv2D)         (None, 6, 12, 384)           442368    ['activation_185[0][0]']
#
#  conv2d_186 (Conv2D)         (None, 6, 12, 384)           442368    ['activation_185[0][0]']
#
#  average_pooling2d_17 (Aver  (None, 6, 12, 2048)          0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_179 (Conv2D)         (None, 6, 12, 320)           655360    ['mixed9[0][0]']
#
#  batch_normalization_181 (B  (None, 6, 12, 384)           1152      ['conv2d_181[0][0]']
#  atchNormalization)
#
#  batch_normalization_182 (B  (None, 6, 12, 384)           1152      ['conv2d_182[0][0]']
#  atchNormalization)
#
#  batch_normalization_185 (B  (None, 6, 12, 384)           1152      ['conv2d_185[0][0]']
#  atchNormalization)
#
#  batch_normalization_186 (B  (None, 6, 12, 384)           1152      ['conv2d_186[0][0]']
#  atchNormalization)
#
#  conv2d_187 (Conv2D)         (None, 6, 12, 192)           393216    ['average_pooling2d_17[0][0]']
#
#  batch_normalization_179 (B  (None, 6, 12, 320)           960       ['conv2d_179[0][0]']
#  atchNormalization)
#
#  activation_182 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_181[0][0
#  )                                                                  ]']
#
#  activation_183 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_182[0][0
#  )                                                                  ]']
#
#  activation_186 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_185[0][0
#  )                                                                  ]']
#
#  activation_187 (Activation  (None, 6, 12, 384)           0         ['batch_normalization_186[0][0
#  )                                                                  ]']
#
#  batch_normalization_187 (B  (None, 6, 12, 192)           576       ['conv2d_187[0][0]']
#  atchNormalization)
#
#  activation_180 (Activation  (None, 6, 12, 320)           0         ['batch_normalization_179[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (None, 6, 12, 768)           0         ['activation_182[0][0]',
#                                                                      'activation_183[0][0]']
#
#  concatenate_3 (Concatenate  (None, 6, 12, 768)           0         ['activation_186[0][0]',
#  )                                                                   'activation_187[0][0]']
#
#  activation_188 (Activation  (None, 6, 12, 192)           0         ['batch_normalization_187[0][0
#  )                                                                  ]']
#
#  mixed10 (Concatenate)       (None, 6, 12, 2048)          0         ['activation_180[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_3[0][0]',
#                                                                      'activation_188[0][0]']
#
#  flatten_1 (Flatten)         (None, 147456)               0         ['mixed10[0][0]']
#
#  dense_6 (Dense)             (None, 1024)                 1509959   ['flatten_1[0][0]']
#                                                           68
#
#  dense_7 (Dense)             (None, 512)                  524800    ['dense_6[0][0]']
#
#  dense_8 (Dense)             (None, 256)                  131328    ['dense_7[0][0]']
#
#  dense_9 (Dense)             (None, 128)                  32896     ['dense_8[0][0]']
#
#  dense_10 (Dense)            (None, 32)                   4128      ['dense_9[0][0]']
#
#  dense_11 (Dense)            (None, 1)                    33        ['dense_10[0][0]']
#
#  activation_189 (Activation  (None, 1)                    0         ['dense_11[0][0]']
#  )
#
# ==================================================================================================
# Total params: 173491937 (661.82 MB)
# Trainable params: 151689153 (578.65 MB)
# Non-trainable params: 21802784 (83.17 MB)
# __________________________________________________________________________________________________

# %%
# savingPath = os.makedirs('/content/drive/MyDrive/InceptionV3Weights/1')
checkpoint_path = '/content/drive/MyDrive/InceptionV3Weights/1'
checkpoint_dir = os.path.dirname(checkpoint_path)
print(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path, save_weights_only=True, save_best_only=True, verbose= 1)
# Out:
# /content/drive/MyDrive/InceptionV3Weights/1

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate= 0.001), loss= 'binary_crossentropy',
              metrics= [tf.keras.metrics.BinaryAccuracy(name="Binary_accuracy"),
                        tf.keras.metrics.Precision(name='Precision'),
                        tf.keras.metrics.Recall(name='Recall'),
                        tf.keras.metrics.TruePositives(name='TP'),
                        tf.keras.metrics.TrueNegatives(name='TN'),
                        tf.keras.metrics.FalseNegatives(name='FN'),
                        tf.keras.metrics.FalsePositives(name='FP'),
                        tf.keras.metrics.AUC(name='AUC')])

# %%
history = model.fit(
            train_generator,
            validation_data = test_generator,
            epochs = 40,
            verbose = 1,
            callbacks = [cp_callback])

# %%
model2 = Model(pre_trained_model.input, x)

# %%
model2.compile(optimizer=tf.keras.optimizers.Adam(learning_rate= 0.001), loss= 'binary_crossentropy',
               metrics= [tf.keras.metrics.BinaryAccuracy(name="Binary_accuracy"),
                        tf.keras.metrics.Precision(name='Precision'),
                        tf.keras.metrics.Recall(name='Recall'),
                        tf.keras.metrics.TruePositives(name='TP'),
                        tf.keras.metrics.TrueNegatives(name='TN'),
                        tf.keras.metrics.FalseNegatives(name='FN'),
                        tf.keras.metrics.FalsePositives(name='FP'),
                        tf.keras.metrics.AUC(name='AUC')])

# %%
model2.load_weights(checkpoint_path)

# %%
model2.evaluate(test_generator)
# Out:
# 41/41 [==============================] - 97s 2s/step - loss: 0.4650 - Binary_accuracy: 0.8571 - Precision: 0.8984 - Recall: 0.8116 - TP: 168.0000 - TN: 180.0000 - FN: 39.0000 - FP: 19.0000 - AUC: 0.9112
# [0.4650360643863678,
#  0.8571428656578064,
#  0.8983957171440125,
#  0.8115941882133484,
#  168.0,
#  180.0,
#  39.0,
#  19.0,
#  0.9111863970756531]

# %%
base_dir = '/content/drive/MyDrive/TIFF PET-CTWholeDataset'

training_set_dir = os.path.join(base_dir, 'trainingSet')
test_set_dir = os.path.join(base_dir, 'testSet')

train_lungCancer_dir = os.path.join(training_set_dir, 'lungCancer')
train_normal_dir = os.path.join(training_set_dir, 'normal')
test_lungCancer_dir = os.path.join(test_set_dir, 'lungCancer')
test_normal_dir = os.path.join(test_set_dir, 'normal')

print(test_normal_dir)
print(test_lungCancer_dir)
# Out:
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/normal
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer

# %%
fileNames2 = os.listdir(test_lungCancer_dir)
filePaths2 = []

for i in fileNames2:
    path = '/content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/'
    new_path = path + i
    filePaths2.append(new_path)


my_y_pred2 = []


for fn in filePaths2:
    img = tf.keras.utils.load_img(fn, target_size=(245, 457))
    x = tf.keras.utils.img_to_array(img)
    x /= 255
    x = np.expand_dims(x, axis=0)
    images = np.vstack([x])
    classes = model2.predict(images, batch_size=10)
    my_y_pred2.append(classes)
    print(classes[0])
    if classes[0]>0.5:
        print(fn + " lunCancer does not exist in this slice")
    else:
        print(fn + " lungCancer exists in this slice")


y_pred2 = np.array(my_y_pred2)
y_pred2.resize(1,len(my_y_pred2))
y_pred2
# Out:
# 1/1 [==============================] - 1s 1s/step
# [0.00088693]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (10).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 154ms/step
# [0.00083663]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (1).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 164ms/step
# [0.00118003]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (11).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 166ms/step
# [0.00324874]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (13).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 139ms/step
# [0.00570195]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (12).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 150ms/step
# [0.00620392]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (15).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 153ms/step
# [0.01611916]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (14).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 168ms/step
# [0.00281272]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (17).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 149ms/step
# [0.00884715]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (16).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 166ms/step
# [0.01108314]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (18).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 157ms/step
# [0.06976361]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (19).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 164ms/step
# [0.00094409]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (2).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 147ms/step
# [4.0661722e-05]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (20).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 168ms/step
# [9.767904e-08]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (21).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 149ms/step
# [4.516607e-06]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (25).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 152ms/step
# [2.2707295e-06]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (24).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 171ms/step
# [1.897335e-06]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (23).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 137ms/step
# [5.646352e-09]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (22).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 129ms/step
# [0.00011573]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (30).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 127ms/step
# [0.00089564]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (3).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 154ms/step
# [0.00044697]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (31).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 150ms/step
# [7.549506e-08]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (27).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 153ms/step
# [4.0614207e-08]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (28).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 153ms/step
# [0.01392579]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (4).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 163ms/step
# [2.5488282e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (29).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 146ms/step
# [2.3790679e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (26).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 164ms/step
# [0.00022413]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000216 (2).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 145ms/step
# [0.0005472]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (8).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 149ms/step
# [0.0006991]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (9).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 152ms/step
# [0.03462619]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (5).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 152ms/step
# [0.00152604]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (6).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 167ms/step
# [0.0019586]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000156 (7).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 149ms/step
# [1.6747532e-05]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000216 (10).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 149ms/step
# [0.00536375]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000216 (1).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 150ms/step
# [0.00081586]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000216 (7).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 150ms/step
# [0.01629589]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000216 (6).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 161ms/step
# [0.0017429]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000216 (3).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 122ms/step
# [4.9113114e-06]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000216 (9).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 125ms/step
# [0.08141371]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000217 (1).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 127ms/step
# [0.00011854]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000216 (8).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 145ms/step
# [0.06181797]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000216 (4).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 163ms/step
# [0.00194626]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000216 (5).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 143ms/step
# [0.00033054]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000217 (10).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 168ms/step
# [0.18613154]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000217 (16).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 146ms/step
# [1.7898827e-05]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000217 (13).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 165ms/step
# [0.00027918]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000217 (3).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 145ms/step
# [2.9941904e-05]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000217 (11).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 149ms/step
# [0.00054509]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000217 (14).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 163ms/step
# [0.00647415]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000217 (2).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 170ms/step
# [0.02660447]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000217 (15).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 126ms/step
# [6.934367e-05]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000217 (12).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 146ms/step
# [4.5404104e-05]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000217 (8).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 157ms/step
# [8.695928e-06]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000218 (1).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 153ms/step
# [0.01592249]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000217 (7).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 152ms/step
# [0.0002558]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000217 (4).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 151ms/step
# [0.11142346]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000217 (6).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 151ms/step
# [1.0801158e-05]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000217 (9).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 157ms/step
# [0.40027332]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000217 (5).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 167ms/step
# [5.93465e-06]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000218 (11).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 149ms/step
# [7.121397e-08]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000218 (10).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 166ms/step
# [3.6185057e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000218 (5).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 154ms/step
# [2.0345443e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000218 (8).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 152ms/step
# [1.46569e-05]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000218 (2).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 151ms/step
# [2.4185385e-05]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000218 (3).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 150ms/step
# [2.5776933e-05]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000218 (4).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 161ms/step
# [9.804676e-08]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000218 (7).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 169ms/step
# [0.00015558]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000218 (12).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 150ms/step
# [5.6708007e-08]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000218 (6).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 166ms/step
# [5.120722e-06]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (11).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 129ms/step
# [0.00032655]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (15).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 127ms/step
# [4.2381097e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (12).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 156ms/step
# [0.00045039]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (16).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 151ms/step
# [0.00018344]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (13).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 154ms/step
# [0.00010257]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (14).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 159ms/step
# [9.869275e-08]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (10).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 150ms/step
# [2.1985875e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000218 (9).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 161ms/step
# [1.2112252e-09]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (1).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 125ms/step
# [4.319298e-05]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (25).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 156ms/step
# [0.00075914]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (24).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 151ms/step
# [8.0761633e-11]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (20).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 151ms/step
# [0.00252425]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (18).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 161ms/step
# [1.6333322e-10]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (21).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 146ms/step
# [1.289947e-10]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (19).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 158ms/step
# [3.554876e-05]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (23).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 154ms/step
# [2.4941744e-06]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (17).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 164ms/step
# [1.8201962e-10]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (2).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 145ms/step
# [4.0136445e-08]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (22).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 151ms/step
# [4.6170877e-05]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (28).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 150ms/step
# [2.0003858e-08]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (32).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 150ms/step
# [8.340525e-06]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (30).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 153ms/step
# [5.0300863e-10]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (3).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 163ms/step
# [9.823514e-05]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (27).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 147ms/step
# [2.290028e-05]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (29).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 161ms/step
# [0.00255192]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (26).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 138ms/step
# [1.7256841e-08]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (33).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 124ms/step
# [1.9692212e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (31).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 123ms/step
# [2.8097837e-08]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (41).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 143ms/step
# [2.8536706e-09]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (38).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 149ms/step
# [1.0975502e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (36).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 152ms/step
# [3.962564e-09]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (37).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 161ms/step
# [7.8360824e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (35).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 150ms/step
# [1.615664e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (40).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 171ms/step
# [2.738407e-10]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (39).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 135ms/step
# [8.961769e-09]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (4).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 125ms/step
# [5.238255e-08]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (34).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 125ms/step
# [8.298992e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (8).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 146ms/step
# [6.821835e-06]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (1).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 149ms/step
# [3.4764128e-10]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (42).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 149ms/step
# [4.1304258e-08]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (5).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 163ms/step
# [2.1249797e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (6).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 146ms/step
# [6.252508e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (10).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 150ms/step
# [1.5455151e-06]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (7).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 153ms/step
# [1.4478921e-05]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (11).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 165ms/step
# [4.998512e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000223 (9).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 144ms/step
# [0.02442528]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (17).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 150ms/step
# [8.8912066e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (14).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 171ms/step
# [0.0198712]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (19).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 123ms/step
# [4.407506e-06]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (12).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 136ms/step
# [1.0424266e-06]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (2).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 127ms/step
# [5.9716605e-08]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (13).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 154ms/step
# [4.7959446e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (15).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 151ms/step
# [0.00030561]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (16).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 151ms/step
# [0.10277775]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (18).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 173ms/step
# [0.00027283]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (20).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 128ms/step
# [3.5196242e-06]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (28).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 153ms/step
# [4.5748956e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (24).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 152ms/step
# [2.6638567e-05]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (22).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 151ms/step
# [1.6889526e-08]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (27).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 151ms/step
# [0.00061996]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (21).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 158ms/step
# [1.1498016e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (26).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 152ms/step
# [4.98639e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (23).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 160ms/step
# [3.5672414e-09]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (25).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 174ms/step
# [0.00010629]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (29).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 127ms/step
# [6.7335877e-06]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (37).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 144ms/step
# [0.00017111]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (33).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 150ms/step
# [5.3527486e-07]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (38).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 148ms/step
# [3.974812e-09]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (3).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 168ms/step
# [4.5267925e-06]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (32).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 125ms/step
# [1.1548568e-05]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (31).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 122ms/step
# [4.4114377e-06]
# /content/drive/MyDrive/TIFF PET-CTWholeDataset/testSet/lungCancer/0000226 (34).tif lungCancer exists in this slice

# %%
base_dir3 = '/content/drive/MyDrive/2ExternalDataSet'

# %%
fileNames2 = os.listdir(base_dir3)
filePaths2 = []

for i in fileNames2:
    path = '/content/drive/MyDrive/2ExternalDataSet/'
    new_path = path + i
    filePaths2.append(new_path)


my_y_pred2 = []


for fn in filePaths2:
    img = tf.keras.utils.load_img(fn, target_size=(245, 457))
    x = tf.keras.utils.img_to_array(img)
    x /= 255
    x = np.expand_dims(x, axis=0)
    images = np.vstack([x])
    classes = model2.predict(images, batch_size=10)
    my_y_pred2.append(classes)
    print(classes[0])
    if classes[0]>0.5:
        print(fn + " lunCancer does not exist in this slice")
    else:
        print(fn + " lungCancer exists in this slice")


y_pred2 = np.array(my_y_pred2)
y_pred2.resize(1,len(my_y_pred2))
y_pred2
# Out:
# 1/1 [==============================] - 2s 2s/step
# [0.00569852]
# /content/drive/MyDrive/2ExternalDataSet/197 (77).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 455ms/step
# [0.02296]
# /content/drive/MyDrive/2ExternalDataSet/197 (79).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 481ms/step
# [0.01149152]
# /content/drive/MyDrive/2ExternalDataSet/197 (78).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 493ms/step
# [0.00445311]
# /content/drive/MyDrive/2ExternalDataSet/197 (81).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 502ms/step
# [0.01455113]
# /content/drive/MyDrive/2ExternalDataSet/197 (80).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 499ms/step
# [0.00341729]
# /content/drive/MyDrive/2ExternalDataSet/197 (82).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 439ms/step
# [0.01169947]
# /content/drive/MyDrive/2ExternalDataSet/197 (83).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 437ms/step
# [0.08670168]
# /content/drive/MyDrive/2ExternalDataSet/197 (84).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 545ms/step
# [0.07873849]
# /content/drive/MyDrive/2ExternalDataSet/197 (85).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 499ms/step
# [0.02771479]
# /content/drive/MyDrive/2ExternalDataSet/197 (86).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 464ms/step
# [0.0109855]
# /content/drive/MyDrive/2ExternalDataSet/197 (88).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 847ms/step
# [0.04261534]
# /content/drive/MyDrive/2ExternalDataSet/197 (87).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 488ms/step
# [0.0171087]
# /content/drive/MyDrive/2ExternalDataSet/197 (90).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 448ms/step
# [0.03145713]
# /content/drive/MyDrive/2ExternalDataSet/197 (89).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 504ms/step
# [0.02752298]
# /content/drive/MyDrive/2ExternalDataSet/197 (91).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 448ms/step
# [0.02432935]
# /content/drive/MyDrive/2ExternalDataSet/197 (92).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 452ms/step
# [0.01081807]
# /content/drive/MyDrive/2ExternalDataSet/197 (94).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 479ms/step
# [0.01516214]
# /content/drive/MyDrive/2ExternalDataSet/197 (93).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 536ms/step
# [0.01069528]
# /content/drive/MyDrive/2ExternalDataSet/197 (96).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 537ms/step
# [0.0054196]
# /content/drive/MyDrive/2ExternalDataSet/197 (95).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 530ms/step
# [0.01302145]
# /content/drive/MyDrive/2ExternalDataSet/197 (97).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 442ms/step
# [0.00989562]
# /content/drive/MyDrive/2ExternalDataSet/197 (98).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 524ms/step
# [0.8490687]
# /content/drive/MyDrive/2ExternalDataSet/198 (69).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 535ms/step
# [0.00942181]
# /content/drive/MyDrive/2ExternalDataSet/197 (99).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 522ms/step
# [0.84474987]
# /content/drive/MyDrive/2ExternalDataSet/198 (70).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 468ms/step
# [0.2556574]
# /content/drive/MyDrive/2ExternalDataSet/198 (73).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 539ms/step
# [0.46192715]
# /content/drive/MyDrive/2ExternalDataSet/198 (71).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 513ms/step
# [0.44286725]
# /content/drive/MyDrive/2ExternalDataSet/198 (72).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 461ms/step
# [0.3610682]
# /content/drive/MyDrive/2ExternalDataSet/198 (74).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 525ms/step
# [0.33337948]
# /content/drive/MyDrive/2ExternalDataSet/198 (75).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 458ms/step
# [0.15621369]
# /content/drive/MyDrive/2ExternalDataSet/198 (76).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 466ms/step
# [0.4960286]
# /content/drive/MyDrive/2ExternalDataSet/198 (78).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 488ms/step
# [0.3294228]
# /content/drive/MyDrive/2ExternalDataSet/198 (77).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 522ms/step
# [0.37007484]
# /content/drive/MyDrive/2ExternalDataSet/198 (79).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 484ms/step
# [0.22419842]
# /content/drive/MyDrive/2ExternalDataSet/198 (80).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 495ms/step
# [0.4093537]
# /content/drive/MyDrive/2ExternalDataSet/198 (81).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 483ms/step
# [0.3934514]
# /content/drive/MyDrive/2ExternalDataSet/198 (82).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 477ms/step
# [0.4533025]
# /content/drive/MyDrive/2ExternalDataSet/198 (84).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 453ms/step
# [0.44304228]
# /content/drive/MyDrive/2ExternalDataSet/198 (83).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 421ms/step
# [0.32911164]
# /content/drive/MyDrive/2ExternalDataSet/198 (86).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 426ms/step
# [0.36633947]
# /content/drive/MyDrive/2ExternalDataSet/198 (85).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 429ms/step
# [0.613216]
# /content/drive/MyDrive/2ExternalDataSet/199 (50).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 530ms/step
# [0.5562099]
# /content/drive/MyDrive/2ExternalDataSet/199 (49).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 442ms/step
# [0.33050427]
# /content/drive/MyDrive/2ExternalDataSet/199 (52).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 616ms/step
# [0.44556585]
# /content/drive/MyDrive/2ExternalDataSet/199 (51).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 530ms/step
# [0.32630146]
# /content/drive/MyDrive/2ExternalDataSet/199 (53).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 590ms/step
# [0.18563953]
# /content/drive/MyDrive/2ExternalDataSet/199 (54).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 542ms/step
# [0.11946729]
# /content/drive/MyDrive/2ExternalDataSet/199 (56).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 535ms/step
# [0.09226385]
# /content/drive/MyDrive/2ExternalDataSet/199 (55).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 565ms/step
# [0.49415874]
# /content/drive/MyDrive/2ExternalDataSet/199 (58).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 477ms/step
# [0.16329168]
# /content/drive/MyDrive/2ExternalDataSet/199 (57).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 501ms/step
# [0.5027686]
# /content/drive/MyDrive/2ExternalDataSet/199 (59).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 543ms/step
# [0.30633706]
# /content/drive/MyDrive/2ExternalDataSet/199 (60).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 535ms/step
# [0.3406723]
# /content/drive/MyDrive/2ExternalDataSet/199 (61).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 493ms/step
# [0.1645506]
# /content/drive/MyDrive/2ExternalDataSet/199 (62).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 477ms/step
# [0.41111714]
# /content/drive/MyDrive/2ExternalDataSet/199 (64).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 484ms/step
# [0.20655829]
# /content/drive/MyDrive/2ExternalDataSet/199 (63).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 424ms/step
# [0.2023031]
# /content/drive/MyDrive/2ExternalDataSet/199 (66).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 451ms/step
# [0.24512488]
# /content/drive/MyDrive/2ExternalDataSet/199 (67).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 427ms/step
# [0.41467378]
# /content/drive/MyDrive/2ExternalDataSet/199 (65).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 474ms/step
# [0.05270046]
# /content/drive/MyDrive/2ExternalDataSet/200 (100).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 425ms/step
# [0.0124582]
# /content/drive/MyDrive/2ExternalDataSet/200 (101).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 521ms/step
# [0.01684763]
# /content/drive/MyDrive/2ExternalDataSet/200 (102).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 513ms/step
# [0.02780786]
# /content/drive/MyDrive/2ExternalDataSet/200 (103).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 464ms/step
# [0.03768776]
# /content/drive/MyDrive/2ExternalDataSet/200 (104).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 438ms/step
# [0.00445106]
# /content/drive/MyDrive/2ExternalDataSet/200 (105).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 457ms/step
# [0.00276074]
# /content/drive/MyDrive/2ExternalDataSet/200 (107).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 445ms/step
# [0.0023939]
# /content/drive/MyDrive/2ExternalDataSet/200 (106).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 517ms/step
# [0.00116122]
# /content/drive/MyDrive/2ExternalDataSet/200 (108).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 527ms/step
# [0.00078775]
# /content/drive/MyDrive/2ExternalDataSet/200 (109).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 467ms/step
# [0.00243479]
# /content/drive/MyDrive/2ExternalDataSet/200 (111).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 465ms/step
# [0.00181777]
# /content/drive/MyDrive/2ExternalDataSet/200 (110).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 564ms/step
# [0.00161313]
# /content/drive/MyDrive/2ExternalDataSet/200 (113).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 563ms/step
# [0.00083335]
# /content/drive/MyDrive/2ExternalDataSet/200 (112).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 430ms/step
# [0.00195056]
# /content/drive/MyDrive/2ExternalDataSet/200 (114).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 535ms/step
# [0.00402616]
# /content/drive/MyDrive/2ExternalDataSet/200 (115).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 571ms/step
# [0.00536113]
# /content/drive/MyDrive/2ExternalDataSet/200 (117).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 527ms/step
# [0.00800472]
# /content/drive/MyDrive/2ExternalDataSet/200 (116).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 541ms/step
# [0.00915878]
# /content/drive/MyDrive/2ExternalDataSet/200 (118).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 545ms/step
# [0.01661814]
# /content/drive/MyDrive/2ExternalDataSet/200 (119).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 526ms/step
# [0.01239345]
# /content/drive/MyDrive/2ExternalDataSet/200 (120).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 540ms/step
# [0.01315768]
# /content/drive/MyDrive/2ExternalDataSet/200 (122).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 443ms/step
# [0.00636173]
# /content/drive/MyDrive/2ExternalDataSet/200 (121).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 504ms/step
# [0.01201436]
# /content/drive/MyDrive/2ExternalDataSet/200 (123).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 426ms/step
# [0.08571126]
# /content/drive/MyDrive/2ExternalDataSet/200 (125).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 451ms/step
# [0.06779866]
# /content/drive/MyDrive/2ExternalDataSet/200 (124).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 528ms/step
# [0.11568332]
# /content/drive/MyDrive/2ExternalDataSet/200 (126).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 505ms/step
# [0.05425997]
# /content/drive/MyDrive/2ExternalDataSet/200 (127).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 464ms/step
# [0.04915668]
# /content/drive/MyDrive/2ExternalDataSet/200 (129).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 504ms/step
# [0.04455611]
# /content/drive/MyDrive/2ExternalDataSet/200 (128).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 525ms/step
# [0.15984942]
# /content/drive/MyDrive/2ExternalDataSet/200 (130).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 481ms/step
# [0.25704506]
# /content/drive/MyDrive/2ExternalDataSet/202 (100).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 511ms/step
# [0.38362718]
# /content/drive/MyDrive/2ExternalDataSet/200 (131).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 426ms/step
# [0.3569723]
# /content/drive/MyDrive/2ExternalDataSet/200 (132).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 431ms/step
# [0.22032607]
# /content/drive/MyDrive/2ExternalDataSet/202 (101).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 514ms/step
# [0.46095514]
# /content/drive/MyDrive/2ExternalDataSet/202 (103).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 463ms/step
# [0.62856275]
# /content/drive/MyDrive/2ExternalDataSet/202 (102).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 435ms/step
# [0.27544853]
# /content/drive/MyDrive/2ExternalDataSet/202 (104).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 442ms/step
# [0.18377668]
# /content/drive/MyDrive/2ExternalDataSet/202 (105).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 426ms/step
# [0.08879928]
# /content/drive/MyDrive/2ExternalDataSet/202 (106).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 460ms/step
# [0.27524188]
# /content/drive/MyDrive/2ExternalDataSet/202 (107).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 402ms/step
# [0.34814593]
# /content/drive/MyDrive/2ExternalDataSet/202 (108).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 462ms/step
# [0.7249207]
# /content/drive/MyDrive/2ExternalDataSet/202 (109).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 453ms/step
# [0.21857947]
# /content/drive/MyDrive/2ExternalDataSet/202 (79).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 428ms/step
# [0.76500565]
# /content/drive/MyDrive/2ExternalDataSet/202 (110).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 586ms/step
# [0.03913593]
# /content/drive/MyDrive/2ExternalDataSet/202 (80).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 486ms/step
# [0.0281325]
# /content/drive/MyDrive/2ExternalDataSet/202 (81).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 574ms/step
# [0.03219946]
# /content/drive/MyDrive/2ExternalDataSet/202 (82).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 442ms/step
# [0.0523744]
# /content/drive/MyDrive/2ExternalDataSet/202 (83).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 443ms/step
# [0.0657983]
# /content/drive/MyDrive/2ExternalDataSet/202 (85).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 440ms/step
# [0.11540767]
# /content/drive/MyDrive/2ExternalDataSet/202 (84).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 530ms/step
# [0.05681253]
# /content/drive/MyDrive/2ExternalDataSet/202 (87).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 449ms/step
# [0.06119009]
# /content/drive/MyDrive/2ExternalDataSet/202 (86).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 541ms/step
# [0.04283364]
# /content/drive/MyDrive/2ExternalDataSet/202 (89).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 421ms/step
# [0.03254895]
# /content/drive/MyDrive/2ExternalDataSet/202 (88).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 420ms/step
# [0.02379668]
# /content/drive/MyDrive/2ExternalDataSet/202 (92).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 442ms/step
# [0.07086676]
# /content/drive/MyDrive/2ExternalDataSet/202 (90).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 522ms/step
# [0.03886474]
# /content/drive/MyDrive/2ExternalDataSet/202 (91).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 448ms/step
# [0.02602541]
# /content/drive/MyDrive/2ExternalDataSet/202 (93).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 447ms/step
# [0.01908312]
# /content/drive/MyDrive/2ExternalDataSet/202 (94).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 428ms/step
# [0.04183934]
# /content/drive/MyDrive/2ExternalDataSet/202 (96).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 450ms/step
# [0.01917495]
# /content/drive/MyDrive/2ExternalDataSet/202 (95).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 484ms/step
# [0.09441344]
# /content/drive/MyDrive/2ExternalDataSet/202 (97).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 492ms/step
# [0.09728386]
# /content/drive/MyDrive/2ExternalDataSet/202 (98).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 409ms/step
# [0.14184135]
# /content/drive/MyDrive/2ExternalDataSet/202 (99).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 431ms/step
# [0.81842804]
# /content/drive/MyDrive/2ExternalDataSet/203 (31).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 443ms/step
# [0.52144843]
# /content/drive/MyDrive/2ExternalDataSet/203 (33).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 458ms/step
# [0.7557685]
# /content/drive/MyDrive/2ExternalDataSet/203 (32).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 447ms/step
# [0.8166618]
# /content/drive/MyDrive/2ExternalDataSet/203 (34).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 435ms/step
# [0.88322115]
# /content/drive/MyDrive/2ExternalDataSet/203 (35).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 428ms/step
# [0.83522516]
# /content/drive/MyDrive/2ExternalDataSet/203 (36).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 527ms/step
# [0.90523124]
# /content/drive/MyDrive/2ExternalDataSet/203 (37).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 463ms/step
# [0.9047907]
# /content/drive/MyDrive/2ExternalDataSet/203 (38).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 557ms/step
# [0.9903768]
# /content/drive/MyDrive/2ExternalDataSet/203 (40).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 464ms/step
# [0.92980736]
# /content/drive/MyDrive/2ExternalDataSet/203 (39).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 448ms/step
# [0.9840696]
# /content/drive/MyDrive/2ExternalDataSet/203 (41).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 565ms/step
# [0.93090105]
# /content/drive/MyDrive/2ExternalDataSet/203 (43).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 552ms/step
# [0.8976647]
# /content/drive/MyDrive/2ExternalDataSet/203 (42).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 419ms/step
# [0.8797134]
# /content/drive/MyDrive/2ExternalDataSet/203 (44).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 476ms/step
# [0.77016103]
# /content/drive/MyDrive/2ExternalDataSet/203 (45).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 520ms/step
# [0.932186]
# /content/drive/MyDrive/2ExternalDataSet/203 (46).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 460ms/step
# [0.960025]
# /content/drive/MyDrive/2ExternalDataSet/203 (47).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 582ms/step
# [0.9391186]
# /content/drive/MyDrive/2ExternalDataSet/203 (48).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 459ms/step
# [0.95349205]
# /content/drive/MyDrive/2ExternalDataSet/203 (49).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 455ms/step
# [0.9086125]
# /content/drive/MyDrive/2ExternalDataSet/203 (50).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 449ms/step
# [0.9462527]
# /content/drive/MyDrive/2ExternalDataSet/203 (51).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 476ms/step
# [0.8870011]
# /content/drive/MyDrive/2ExternalDataSet/203 (52).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 455ms/step
# [0.66421723]
# /content/drive/MyDrive/2ExternalDataSet/203 (53).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 440ms/step
# [0.57674897]
# /content/drive/MyDrive/2ExternalDataSet/203 (54).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 436ms/step
# [0.4222431]
# /content/drive/MyDrive/2ExternalDataSet/203 (55).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 466ms/step
# [0.48878807]
# /content/drive/MyDrive/2ExternalDataSet/203 (57).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 438ms/step
# [0.27043754]
# /content/drive/MyDrive/2ExternalDataSet/203 (56).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 437ms/step
# [0.6332573]
# /content/drive/MyDrive/2ExternalDataSet/203 (58).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 406ms/step
# [0.53894436]
# /content/drive/MyDrive/2ExternalDataSet/203 (59).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 417ms/step
# [0.66463906]
# /content/drive/MyDrive/2ExternalDataSet/203 (60).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 458ms/step
# [0.77321523]
# /content/drive/MyDrive/2ExternalDataSet/203 (62).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 448ms/step
# [0.6854373]
# /content/drive/MyDrive/2ExternalDataSet/203 (61).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 435ms/step
# [0.91899526]
# /content/drive/MyDrive/2ExternalDataSet/203 (63).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 505ms/step
# [0.90801454]
# /content/drive/MyDrive/2ExternalDataSet/203 (64).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 436ms/step
# [0.77903944]
# /content/drive/MyDrive/2ExternalDataSet/203 (65).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 440ms/step
# [0.87494576]
# /content/drive/MyDrive/2ExternalDataSet/203 (67).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 441ms/step
# [0.84810567]
# /content/drive/MyDrive/2ExternalDataSet/203 (66).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 559ms/step
# [0.73802197]
# /content/drive/MyDrive/2ExternalDataSet/203 (68).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 477ms/step
# [0.8042619]
# /content/drive/MyDrive/2ExternalDataSet/203 (69).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 481ms/step
# [0.725831]
# /content/drive/MyDrive/2ExternalDataSet/203 (70).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 580ms/step
# [0.49526381]
# /content/drive/MyDrive/2ExternalDataSet/203 (71).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 427ms/step
# [0.5915704]
# /content/drive/MyDrive/2ExternalDataSet/203 (72).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 447ms/step
# [0.71331674]
# /content/drive/MyDrive/2ExternalDataSet/203 (74).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 427ms/step
# [0.74771357]
# /content/drive/MyDrive/2ExternalDataSet/203 (75).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 439ms/step
# [0.5377475]
# /content/drive/MyDrive/2ExternalDataSet/203 (73).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 447ms/step
# [0.718563]
# /content/drive/MyDrive/2ExternalDataSet/203 (76).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 414ms/step
# [0.7705533]
# /content/drive/MyDrive/2ExternalDataSet/203 (77).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 431ms/step
# [0.7625293]
# /content/drive/MyDrive/2ExternalDataSet/203 (78).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 445ms/step
# [0.8077438]
# /content/drive/MyDrive/2ExternalDataSet/203 (80).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 409ms/step
# [0.9091957]
# /content/drive/MyDrive/2ExternalDataSet/203 (79).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 439ms/step
# [0.97548586]
# /content/drive/MyDrive/2ExternalDataSet/206 (128).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 440ms/step
# [0.8922665]
# /content/drive/MyDrive/2ExternalDataSet/206 (129).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 438ms/step
# [0.93247855]
# /content/drive/MyDrive/2ExternalDataSet/206 (130).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 483ms/step
# [0.9650001]
# /content/drive/MyDrive/2ExternalDataSet/206 (131).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 511ms/step
# [0.9803996]
# /content/drive/MyDrive/2ExternalDataSet/206 (133).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 457ms/step
# [0.95979905]
# /content/drive/MyDrive/2ExternalDataSet/206 (132).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 402ms/step
# [0.9784565]
# /content/drive/MyDrive/2ExternalDataSet/206 (134).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 451ms/step
# [0.9569589]
# /content/drive/MyDrive/2ExternalDataSet/206 (135).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 449ms/step
# [0.810424]
# /content/drive/MyDrive/2ExternalDataSet/208 (109).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 431ms/step
# [0.50502884]
# /content/drive/MyDrive/2ExternalDataSet/208 (110).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 439ms/step
# [0.17584208]
# /content/drive/MyDrive/2ExternalDataSet/208 (112).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 451ms/step
# [0.35941854]
# /content/drive/MyDrive/2ExternalDataSet/208 (111).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 436ms/step
# [0.20103833]
# /content/drive/MyDrive/2ExternalDataSet/208 (114).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 446ms/step
# [0.2226715]
# /content/drive/MyDrive/2ExternalDataSet/208 (113).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 481ms/step
# [0.23546416]
# /content/drive/MyDrive/2ExternalDataSet/208 (115).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 443ms/step
# [0.08930458]
# /content/drive/MyDrive/2ExternalDataSet/208 (117).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 504ms/step
# [0.1833977]
# /content/drive/MyDrive/2ExternalDataSet/208 (116).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 557ms/step
# [0.46255782]
# /content/drive/MyDrive/2ExternalDataSet/208 (119).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 535ms/step
# [0.27521792]
# /content/drive/MyDrive/2ExternalDataSet/208 (118).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 492ms/step
# [0.7355246]
# /content/drive/MyDrive/2ExternalDataSet/208 (120).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 461ms/step
# [0.19595635]
# /content/drive/MyDrive/2ExternalDataSet/210 (65).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 507ms/step
# [0.2603414]
# /content/drive/MyDrive/2ExternalDataSet/210 (66).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 504ms/step
# [0.22335269]
# /content/drive/MyDrive/2ExternalDataSet/210 (67).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 440ms/step
# [0.17024225]
# /content/drive/MyDrive/2ExternalDataSet/210 (68).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 425ms/step
# [0.02320222]
# /content/drive/MyDrive/2ExternalDataSet/210 (70).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 529ms/step
# [0.04176318]
# /content/drive/MyDrive/2ExternalDataSet/210 (69).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 445ms/step
# [0.03682145]
# /content/drive/MyDrive/2ExternalDataSet/210 (71).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 440ms/step
# [0.0460224]
# /content/drive/MyDrive/2ExternalDataSet/210 (72).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 494ms/step
# [0.02625924]
# /content/drive/MyDrive/2ExternalDataSet/210 (73).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 461ms/step
# [0.01232518]
# /content/drive/MyDrive/2ExternalDataSet/210 (74).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 530ms/step
# [0.00828032]
# /content/drive/MyDrive/2ExternalDataSet/210 (76).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 552ms/step
# [0.01833022]
# /content/drive/MyDrive/2ExternalDataSet/210 (77).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 527ms/step
# [0.00901872]
# /content/drive/MyDrive/2ExternalDataSet/210 (75).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 445ms/step
# [0.04272242]
# /content/drive/MyDrive/2ExternalDataSet/210 (79).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 440ms/step
# [0.02069703]
# /content/drive/MyDrive/2ExternalDataSet/210 (78).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 515ms/step
# [0.06628676]
# /content/drive/MyDrive/2ExternalDataSet/213 (73).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 437ms/step
# [0.07001109]
# /content/drive/MyDrive/2ExternalDataSet/210 (80).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 446ms/step
# [0.04111543]
# /content/drive/MyDrive/2ExternalDataSet/213 (74).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 406ms/step
# [0.05355972]
# /content/drive/MyDrive/2ExternalDataSet/213 (75).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 414ms/step
# [0.04893045]
# /content/drive/MyDrive/2ExternalDataSet/213 (76).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 435ms/step
# [0.06633696]
# /content/drive/MyDrive/2ExternalDataSet/213 (77).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 452ms/step
# [0.00751537]
# /content/drive/MyDrive/2ExternalDataSet/213 (78).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 405ms/step
# [0.0314536]
# /content/drive/MyDrive/2ExternalDataSet/213 (79).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 528ms/step
# [0.30522725]
# /content/drive/MyDrive/2ExternalDataSet/213 (81).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 444ms/step
# [0.29566318]
# /content/drive/MyDrive/2ExternalDataSet/213 (80).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 449ms/step
# [0.25816268]
# /content/drive/MyDrive/2ExternalDataSet/213 (82).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 574ms/step
# [0.13282016]
# /content/drive/MyDrive/2ExternalDataSet/213 (83).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 461ms/step
# [0.5109675]
# /content/drive/MyDrive/2ExternalDataSet/213 (85).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 548ms/step
# [0.27470368]
# /content/drive/MyDrive/2ExternalDataSet/213 (84).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 432ms/step
# [0.7301167]
# /content/drive/MyDrive/2ExternalDataSet/213 (87).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 443ms/step
# [0.797941]
# /content/drive/MyDrive/2ExternalDataSet/213 (86).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 451ms/step
# [0.8153104]
# /content/drive/MyDrive/2ExternalDataSet/213 (89).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 426ms/step
# [0.7952928]
# /content/drive/MyDrive/2ExternalDataSet/213 (88).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 504ms/step
# [0.79300725]
# /content/drive/MyDrive/2ExternalDataSet/213 (90).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 458ms/step
# [0.6030307]
# /content/drive/MyDrive/2ExternalDataSet/213 (91).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 502ms/step
# [0.95728016]
# /content/drive/MyDrive/2ExternalDataSet/213 (93).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 501ms/step
# [0.7811115]
# /content/drive/MyDrive/2ExternalDataSet/213 (92).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 447ms/step
# [0.8235847]
# /content/drive/MyDrive/2ExternalDataSet/213 (95).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 407ms/step
# [0.78761834]
# /content/drive/MyDrive/2ExternalDataSet/213 (94).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 541ms/step
# [0.8357458]
# /content/drive/MyDrive/2ExternalDataSet/214 (76).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 448ms/step
# [0.7845847]
# /content/drive/MyDrive/2ExternalDataSet/214 (77).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 541ms/step
# [0.9029682]
# /content/drive/MyDrive/2ExternalDataSet/214 (78).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 414ms/step
# [0.9199149]
# /content/drive/MyDrive/2ExternalDataSet/214 (79).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 554ms/step
# [0.6891843]
# /content/drive/MyDrive/2ExternalDataSet/214 (81).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 448ms/step
# [0.77100164]
# /content/drive/MyDrive/2ExternalDataSet/214 (80).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 443ms/step
# [0.5652614]
# /content/drive/MyDrive/2ExternalDataSet/214 (82).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 499ms/step
# [0.6456549]
# /content/drive/MyDrive/2ExternalDataSet/214 (83).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 535ms/step
# [0.6805885]
# /content/drive/MyDrive/2ExternalDataSet/214 (84).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 506ms/step
# [0.6386638]
# /content/drive/MyDrive/2ExternalDataSet/214 (85).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 457ms/step
# [0.64883304]
# /content/drive/MyDrive/2ExternalDataSet/214 (86).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 545ms/step
# [0.72058195]
# /content/drive/MyDrive/2ExternalDataSet/214 (87).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 432ms/step
# [0.83267754]
# /content/drive/MyDrive/2ExternalDataSet/214 (89).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 542ms/step
# [0.59263253]
# /content/drive/MyDrive/2ExternalDataSet/214 (88).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 408ms/step
# [0.93290234]
# /content/drive/MyDrive/2ExternalDataSet/214 (91).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 463ms/step
# [0.8772911]
# /content/drive/MyDrive/2ExternalDataSet/214 (90).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 604ms/step
# [0.9510779]
# /content/drive/MyDrive/2ExternalDataSet/214 (93).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 544ms/step
# [0.91496736]
# /content/drive/MyDrive/2ExternalDataSet/214 (92).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 488ms/step
# [0.9191521]
# /content/drive/MyDrive/2ExternalDataSet/214 (94).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 559ms/step
# [0.67866445]
# /content/drive/MyDrive/2ExternalDataSet/241 (1).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 460ms/step
# [0.7897691]
# /content/drive/MyDrive/2ExternalDataSet/214 (95).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 544ms/step
# [0.5791448]
# /content/drive/MyDrive/2ExternalDataSet/241 (10).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 546ms/step
# [0.7747872]
# /content/drive/MyDrive/2ExternalDataSet/241 (11).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 413ms/step
# [0.44246268]
# /content/drive/MyDrive/2ExternalDataSet/241 (13).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 532ms/step
# [0.6602919]
# /content/drive/MyDrive/2ExternalDataSet/241 (12).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 457ms/step
# [0.6878132]
# /content/drive/MyDrive/2ExternalDataSet/241 (15).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 448ms/step
# [0.6343095]
# /content/drive/MyDrive/2ExternalDataSet/241 (14).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 520ms/step
# [0.47800034]
# /content/drive/MyDrive/2ExternalDataSet/241 (17).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 537ms/step
# [0.5747699]
# /content/drive/MyDrive/2ExternalDataSet/241 (16).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 457ms/step
# [0.47220767]
# /content/drive/MyDrive/2ExternalDataSet/241 (18).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 428ms/step
# [0.59198785]
# /content/drive/MyDrive/2ExternalDataSet/241 (19).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 518ms/step
# [0.62425935]
# /content/drive/MyDrive/2ExternalDataSet/241 (2).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 509ms/step
# [0.48220927]
# /content/drive/MyDrive/2ExternalDataSet/241 (20).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 464ms/step
# [0.29285598]
# /content/drive/MyDrive/2ExternalDataSet/241 (21).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 549ms/step
# [0.21570241]
# /content/drive/MyDrive/2ExternalDataSet/241 (22).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 553ms/step
# [0.27488905]
# /content/drive/MyDrive/2ExternalDataSet/241 (23).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 435ms/step
# [0.26121315]
# /content/drive/MyDrive/2ExternalDataSet/241 (24).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 439ms/step
# [0.4094325]
# /content/drive/MyDrive/2ExternalDataSet/241 (26).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 508ms/step
# [0.45100772]
# /content/drive/MyDrive/2ExternalDataSet/241 (25).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 444ms/step
# [0.33523825]
# /content/drive/MyDrive/2ExternalDataSet/241 (27).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 538ms/step
# [0.5633014]
# /content/drive/MyDrive/2ExternalDataSet/241 (29).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 447ms/step
# [0.50663555]
# /content/drive/MyDrive/2ExternalDataSet/241 (28).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 443ms/step
# [0.6104223]
# /content/drive/MyDrive/2ExternalDataSet/241 (3).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 436ms/step
# [0.54778713]
# /content/drive/MyDrive/2ExternalDataSet/241 (30).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 584ms/step
# [0.4155946]
# /content/drive/MyDrive/2ExternalDataSet/241 (31).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 471ms/step
# [0.28168407]
# /content/drive/MyDrive/2ExternalDataSet/241 (32).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 413ms/step
# [0.12469973]
# /content/drive/MyDrive/2ExternalDataSet/241 (33).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 414ms/step
# [0.1098795]
# /content/drive/MyDrive/2ExternalDataSet/241 (34).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 422ms/step
# [0.30724946]
# /content/drive/MyDrive/2ExternalDataSet/241 (35).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 439ms/step
# [0.71181893]
# /content/drive/MyDrive/2ExternalDataSet/241 (37).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 441ms/step
# [0.495549]
# /content/drive/MyDrive/2ExternalDataSet/241 (36).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 441ms/step
# [0.75210583]
# /content/drive/MyDrive/2ExternalDataSet/241 (39).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 430ms/step
# [0.72542536]
# /content/drive/MyDrive/2ExternalDataSet/241 (38).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 444ms/step
# [0.8287185]
# /content/drive/MyDrive/2ExternalDataSet/241 (40).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 406ms/step
# [0.8126011]
# /content/drive/MyDrive/2ExternalDataSet/241 (4).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 459ms/step
# [0.8392946]
# /content/drive/MyDrive/2ExternalDataSet/241 (5).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 434ms/step
# [0.71691513]
# /content/drive/MyDrive/2ExternalDataSet/241 (6).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 478ms/step
# [0.78481907]
# /content/drive/MyDrive/2ExternalDataSet/241 (8).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 487ms/step
# [0.7293475]
# /content/drive/MyDrive/2ExternalDataSet/241 (7).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 610ms/step
# [0.71122277]
# /content/drive/MyDrive/2ExternalDataSet/241 (9).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 446ms/step
# [0.4963201]
# /content/drive/MyDrive/2ExternalDataSet/265 (100).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 435ms/step
# [0.40581992]
# /content/drive/MyDrive/2ExternalDataSet/265 (101).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 445ms/step
# [0.4605354]
# /content/drive/MyDrive/2ExternalDataSet/265 (102).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 541ms/step
# [0.16267024]
# /content/drive/MyDrive/2ExternalDataSet/265 (104).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 460ms/step
# [0.16924833]
# /content/drive/MyDrive/2ExternalDataSet/265 (103).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 414ms/step
# [0.11513418]
# /content/drive/MyDrive/2ExternalDataSet/265 (105).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 443ms/step
# [0.24817681]
# /content/drive/MyDrive/2ExternalDataSet/265 (106).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 445ms/step
# [0.19851235]
# /content/drive/MyDrive/2ExternalDataSet/265 (107).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 435ms/step
# [0.1413371]
# /content/drive/MyDrive/2ExternalDataSet/265 (108).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 535ms/step
# [0.45792633]
# /content/drive/MyDrive/2ExternalDataSet/265 (110).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 461ms/step
# [0.15796927]
# /content/drive/MyDrive/2ExternalDataSet/265 (109).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 419ms/step
# [0.7149699]
# /content/drive/MyDrive/2ExternalDataSet/265 (111).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 449ms/step
# [0.62750465]
# /content/drive/MyDrive/2ExternalDataSet/265 (113).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 415ms/step
# [0.80061716]
# /content/drive/MyDrive/2ExternalDataSet/265 (112).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 594ms/step
# [0.50829923]
# /content/drive/MyDrive/2ExternalDataSet/265 (114).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 519ms/step
# [0.2446027]
# /content/drive/MyDrive/2ExternalDataSet/265 (115).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 518ms/step
# [0.53608286]
# /content/drive/MyDrive/2ExternalDataSet/265 (116).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 437ms/step
# [0.6607752]
# /content/drive/MyDrive/2ExternalDataSet/265 (117).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 505ms/step
# ...
# 1/1 [==============================] - 0s 457ms/step
# [0.0503842]
# /content/drive/MyDrive/2ExternalDataSet/196 (108).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 407ms/step
# [0.0368251]
# /content/drive/MyDrive/2ExternalDataSet/196 (107).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 453ms/step
# [0.12279781]
# /content/drive/MyDrive/2ExternalDataSet/196 (111).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 448ms/step
# [0.05004642]
# /content/drive/MyDrive/2ExternalDataSet/196 (110).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 471ms/step
# [0.20415483]
# /content/drive/MyDrive/2ExternalDataSet/196 (114).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 561ms/step
# [0.26643157]
# /content/drive/MyDrive/2ExternalDataSet/196 (112).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 549ms/step
# [0.1607984]
# /content/drive/MyDrive/2ExternalDataSet/196 (113).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 563ms/step
# [0.19338028]
# /content/drive/MyDrive/2ExternalDataSet/196 (115).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 446ms/step
# [0.14819968]
# /content/drive/MyDrive/2ExternalDataSet/196 (116).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 450ms/step
# [0.06746652]
# /content/drive/MyDrive/2ExternalDataSet/196 (119).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 499ms/step
# [0.14623544]
# /content/drive/MyDrive/2ExternalDataSet/196 (117).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 526ms/step
# [0.08663576]
# /content/drive/MyDrive/2ExternalDataSet/196 (118).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 579ms/step
# [0.36690643]
# /content/drive/MyDrive/2ExternalDataSet/196 (122).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 406ms/step
# [0.09210098]
# /content/drive/MyDrive/2ExternalDataSet/196 (120).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 599ms/step
# [0.20778005]
# /content/drive/MyDrive/2ExternalDataSet/196 (121).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 526ms/step
# [0.8019558]
# /content/drive/MyDrive/2ExternalDataSet/196 (125).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 577ms/step
# [0.43444288]
# /content/drive/MyDrive/2ExternalDataSet/196 (123).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 524ms/step
# [0.77447486]
# /content/drive/MyDrive/2ExternalDataSet/196 (124).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 565ms/step
# [0.76908803]
# /content/drive/MyDrive/2ExternalDataSet/196 (126).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 474ms/step
# [0.70014375]
# /content/drive/MyDrive/2ExternalDataSet/196 (127).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 508ms/step
# [0.76218003]
# /content/drive/MyDrive/2ExternalDataSet/196 (129).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 415ms/step
# [0.619217]
# /content/drive/MyDrive/2ExternalDataSet/196 (128).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 433ms/step
# [0.80641437]
# /content/drive/MyDrive/2ExternalDataSet/196 (130).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 465ms/step
# [0.11980852]
# /content/drive/MyDrive/2ExternalDataSet/196 (86).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 484ms/step
# [0.1356751]
# /content/drive/MyDrive/2ExternalDataSet/196 (87).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 518ms/step
# [0.07580133]
# /content/drive/MyDrive/2ExternalDataSet/196 (90).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 443ms/step
# [0.01769048]
# /content/drive/MyDrive/2ExternalDataSet/196 (89).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 452ms/step
# [0.03355259]
# /content/drive/MyDrive/2ExternalDataSet/196 (92).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 408ms/step
# [0.02934105]
# /content/drive/MyDrive/2ExternalDataSet/196 (91).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 443ms/step
# [0.00724712]
# /content/drive/MyDrive/2ExternalDataSet/196 (94).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 438ms/step
# [0.01419983]
# /content/drive/MyDrive/2ExternalDataSet/196 (93).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 433ms/step
# [0.02856973]
# /content/drive/MyDrive/2ExternalDataSet/196 (95).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 461ms/step
# [0.01330067]
# /content/drive/MyDrive/2ExternalDataSet/196 (96).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 419ms/step
# [0.05001322]
# /content/drive/MyDrive/2ExternalDataSet/196 (97).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 474ms/step
# [0.08043381]
# /content/drive/MyDrive/2ExternalDataSet/196 (98).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 482ms/step
# [0.01166904]
# /content/drive/MyDrive/2ExternalDataSet/197 (100).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 438ms/step
# [0.12658587]
# /content/drive/MyDrive/2ExternalDataSet/196 (99).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 441ms/step
# [0.03098072]
# /content/drive/MyDrive/2ExternalDataSet/197 (102).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 405ms/step
# [0.00604352]
# /content/drive/MyDrive/2ExternalDataSet/197 (101).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 455ms/step
# [0.23432714]
# /content/drive/MyDrive/2ExternalDataSet/197 (103).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 446ms/step
# [0.1127454]
# /content/drive/MyDrive/2ExternalDataSet/197 (104).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 403ms/step
# [0.06244924]
# /content/drive/MyDrive/2ExternalDataSet/197 (105).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 462ms/step
# [0.1086268]
# /content/drive/MyDrive/2ExternalDataSet/197 (106).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 597ms/step
# [0.03924952]
# /content/drive/MyDrive/2ExternalDataSet/197 (107).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 435ms/step
# [0.02981309]
# /content/drive/MyDrive/2ExternalDataSet/197 (108).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 512ms/step
# [0.04079009]
# /content/drive/MyDrive/2ExternalDataSet/197 (110).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 454ms/step
# [0.02681574]
# /content/drive/MyDrive/2ExternalDataSet/197 (109).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 445ms/step
# [0.09800541]
# /content/drive/MyDrive/2ExternalDataSet/197 (111).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 448ms/step
# [0.05573143]
# /content/drive/MyDrive/2ExternalDataSet/197 (113).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 422ms/step
# [0.09206301]
# /content/drive/MyDrive/2ExternalDataSet/197 (112).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 448ms/step
# [0.0831574]
# /content/drive/MyDrive/2ExternalDataSet/197 (115).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 443ms/step
# [0.03976802]
# /content/drive/MyDrive/2ExternalDataSet/197 (114).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 403ms/step
# [0.02980767]
# /content/drive/MyDrive/2ExternalDataSet/197 (117).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 476ms/step
# [0.11112265]
# /content/drive/MyDrive/2ExternalDataSet/197 (116).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 521ms/step
# [0.08138948]
# /content/drive/MyDrive/2ExternalDataSet/197 (118).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 559ms/step
# [0.0835166]
# /content/drive/MyDrive/2ExternalDataSet/197 (119).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 450ms/step
# [0.20664018]
# /content/drive/MyDrive/2ExternalDataSet/197 (121).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 512ms/step
# [0.41613978]
# /content/drive/MyDrive/2ExternalDataSet/197 (122).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 440ms/step
# [0.16905893]
# /content/drive/MyDrive/2ExternalDataSet/197 (120).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 447ms/step
# [0.8776338]
# /content/drive/MyDrive/2ExternalDataSet/197 (123).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 491ms/step
# [0.9370243]
# /content/drive/MyDrive/2ExternalDataSet/197 (124).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 440ms/step
# [0.171953]
# /content/drive/MyDrive/2ExternalDataSet/197 (126).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 440ms/step
# [0.701861]
# /content/drive/MyDrive/2ExternalDataSet/197 (125).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 535ms/step
# [0.16858247]
# /content/drive/MyDrive/2ExternalDataSet/197 (127).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 434ms/step
# [0.34709936]
# /content/drive/MyDrive/2ExternalDataSet/197 (128).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 444ms/step
# [0.54959995]
# /content/drive/MyDrive/2ExternalDataSet/197 (129).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 1s 540ms/step
# [0.5451713]
# /content/drive/MyDrive/2ExternalDataSet/197 (130).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 441ms/step
# [0.67425424]
# /content/drive/MyDrive/2ExternalDataSet/197 (40).tif lunCancer does not exist in this slice
# 1/1 [==============================] - 0s 448ms/step
# [0.16278464]
# /content/drive/MyDrive/2ExternalDataSet/197 (41).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 504ms/step
# [0.23605487]
# /content/drive/MyDrive/2ExternalDataSet/197 (42).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 455ms/step
# [0.21527459]
# /content/drive/MyDrive/2ExternalDataSet/197 (43).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 530ms/step
# [0.19455394]
# /content/drive/MyDrive/2ExternalDataSet/197 (44).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 532ms/step
# [0.06865896]
# /content/drive/MyDrive/2ExternalDataSet/197 (46).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 535ms/step
# [0.14275947]
# /content/drive/MyDrive/2ExternalDataSet/197 (45).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 456ms/step
# [0.05483622]
# /content/drive/MyDrive/2ExternalDataSet/197 (47).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 428ms/step
# [0.02550485]
# /content/drive/MyDrive/2ExternalDataSet/197 (48).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 514ms/step
# [0.0566921]
# /content/drive/MyDrive/2ExternalDataSet/197 (49).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 517ms/step
# [0.03683548]
# /content/drive/MyDrive/2ExternalDataSet/197 (50).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 468ms/step
# [0.07361463]
# /content/drive/MyDrive/2ExternalDataSet/197 (51).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 448ms/step
# [0.11136611]
# /content/drive/MyDrive/2ExternalDataSet/197 (52).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 524ms/step
# [0.16963044]
# /content/drive/MyDrive/2ExternalDataSet/197 (53).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 450ms/step
# [0.03513045]
# /content/drive/MyDrive/2ExternalDataSet/197 (55).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 446ms/step
# [0.12924828]
# /content/drive/MyDrive/2ExternalDataSet/197 (54).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 519ms/step
# [0.00450942]
# /content/drive/MyDrive/2ExternalDataSet/197 (57).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 448ms/step
# [0.01027865]
# /content/drive/MyDrive/2ExternalDataSet/197 (56).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 417ms/step
# [0.00323173]
# /content/drive/MyDrive/2ExternalDataSet/197 (59).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 444ms/step
# [0.00590082]
# /content/drive/MyDrive/2ExternalDataSet/197 (58).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 482ms/step
# [0.0116659]
# /content/drive/MyDrive/2ExternalDataSet/197 (60).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 512ms/step
# [0.02178641]
# /content/drive/MyDrive/2ExternalDataSet/197 (61).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 408ms/step
# [0.02194815]
# /content/drive/MyDrive/2ExternalDataSet/197 (62).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 523ms/step
# [0.05191007]
# /content/drive/MyDrive/2ExternalDataSet/197 (63).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 529ms/step
# [0.07361892]
# /content/drive/MyDrive/2ExternalDataSet/197 (64).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 491ms/step
# [0.03843784]
# /content/drive/MyDrive/2ExternalDataSet/197 (65).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 528ms/step
# [0.03139731]
# /content/drive/MyDrive/2ExternalDataSet/197 (66).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 441ms/step
# [0.02032758]
# /content/drive/MyDrive/2ExternalDataSet/197 (67).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 445ms/step
# [0.01952317]
# /content/drive/MyDrive/2ExternalDataSet/197 (68).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 436ms/step
# [0.0229654]
# /content/drive/MyDrive/2ExternalDataSet/197 (69).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 441ms/step
# [0.0944987]
# /content/drive/MyDrive/2ExternalDataSet/197 (70).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 535ms/step
# [0.02937941]
# /content/drive/MyDrive/2ExternalDataSet/197 (71).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 457ms/step
# [0.0349471]
# /content/drive/MyDrive/2ExternalDataSet/197 (72).tif lungCancer exists in this slice
# 1/1 [==============================] - 0s 412ms/step
# [0.01637637]
# /content/drive/MyDrive/2ExternalDataSet/197 (73).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 519ms/step
# [0.01588395]
# /content/drive/MyDrive/2ExternalDataSet/197 (75).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 532ms/step
# [0.00867003]
# /content/drive/MyDrive/2ExternalDataSet/197 (74).tif lungCancer exists in this slice
# 1/1 [==============================] - 1s 547ms/step
# [0.00656957]
# /content/drive/MyDrive/2ExternalDataSet/197 (76).tif lungCancer exists in this slice
# array([[0.00569852, 0.02296   , 0.01149152, ..., 0.01588395, 0.00867003,
#         0.00656957]], dtype=float32)

# %%
binary_predictions = (y_pred2.flatten() > 0.5).astype(int)
true_labels = np.zeros_like(binary_predictions)
accuracy = accuracy_score(true_labels, binary_predictions)
print(f"Accuracy: {accuracy:.4f}")
sensitivity = recall_score(true_labels, binary_predictions, pos_label=0)
print(f"Sensitivity (Recall): {sensitivity:.4f}")
# Out:
# Accuracy: 0.8022
# Sensitivity (Recall): 0.8022

# %%
import os
from collections import defaultdict


base_dir3 = '/content/drive/MyDrive/2ExternalDataSet'


fileNames2 = os.listdir(base_dir3)
filePaths2 = []

for i in fileNames2:
    path = '/content/drive/MyDrive/2ExternalDataSet/'
    new_path = path + i
    filePaths2.append(new_path)


patient_predictions = defaultdict(list)


for fn in filePaths2:
    img = tf.keras.utils.load_img(fn, target_size=(245, 457))
    x = tf.keras.utils.img_to_array(img)
    x /= 255  
    x = np.expand_dims(x, axis=0)  
    images = np.vstack([x])  

    
    classes = model2.predict(images, batch_size=10)
    prediction = classes[0][0]  

    
    patient_id = os.path.splitext(fn)[0].split('(')[0].strip()

    
    patient_predictions[patient_id].append(prediction)


final_patient_predictions = []
true_labels = []

# %%
for patient_id, predictions in patient_predictions.items():
    
    binary_predictions = (np.array(predictions) > 0.5).astype(int)  

    
    patient_prediction = 0 if np.sum(binary_predictions == 0) > len(binary_predictions) / 2 else 1

    
    final_patient_predictions.append(patient_prediction)
    true_labels.append(0)  




patient_accuracy = accuracy_score(true_labels, final_patient_predictions)
print(f"Patient-based Accuracy: {patient_accuracy:.4f}")
# Out:
# Patient-based Accuracy: 0.8005
